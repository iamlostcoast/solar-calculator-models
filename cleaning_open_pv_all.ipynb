# %% [markdown]
# # Cleaning the Open PV Data Set
#
# Ultimately, it would be great to be able to merge in the zipcode NREL Solar to this, to use this to predict cost per watt and reported annual energy produced.  There's a ton of blank values, and this is self reported data, so it's probably going to require a LOT of cleaning.

# %%
import pandas as pd
import numpy as np

# %%
# loading in the open_pv_all data set

df = pd.read_csv("./open_pv_all.csv")

# %%
# There are a bunch of columns that are totally null, just going to get rid of all of those.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020303 entries, 0 to 1020302
# Data columns (total 81 columns):
# state                          1020303 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           797958 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      224036 non-null object
# zipcode                        1020298 non-null float64
# install_type                   977722 non-null object
# installer                      702324 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           998765 non-null object
# lbnl_tts_version_year          797958 non-null float64
# lbnl_tts                       797958 non-null object
# city                           798736 non-null object
# utility_clean                  792720 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         998652 non-null object
# annual_PV_prod                 780969 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manuf2_clean                   231607 non-null object
# manuf3_clean                   209653 non-null object
# manuf1_clean                   201121 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# incentivetype                  0 non-null float64
# year_app_implied               0 non-null float64
# year                           68 non-null object
# npv_fit_real                   0 non-null float64
# application_implied            0 non-null float64
# npv_pbi_real                   0 non-null float64
# other_incentive                0 non-null float64
# appraised_cluster              0 non-null float64
# inflation                      0 non-null float64
# other_incentive_real           0 non-null float64
# zip_available                  0 non-null float64
# cust_city                      0 non-null float64
# pbi                            0 non-null float64
# pbi_real                       0 non-null float64
# pbi_length                     5427 non-null float64
# application                    0 non-null float64
# fit_length                     0 non-null float64
# fit_rate                       0 non-null float64
# fit_payment                    0 non-null float64
# _3rdparty_implied              0 non-null float64
# utility                        2117 non-null object
# install_price_real_w           0 non-null float64
# install_price                  0 non-null float64
# installer_clean                0 non-null float64
# manuf1_                        0 non-null float64
# inverter_reported              0 non-null float64
# rebate_real                    0 non-null float64
# model1                         0 non-null float64
# _3rdparty                      0 non-null float64
# inv_model_reported             0 non-null float64
# microinv_solarhub              0 non-null float64
# bipv_3                         5255 non-null float64
# bipv_2                         5255 non-null float64
# bipv_1                         5255 non-null float64
# sales_tax_rate                 0 non-null float64
# sales_tax_cost_real            0 non-null float64
# bipv_all                       0 non-null float64
# thinfilm_all                   0 non-null float64
# china                          0 non-null float64
# sys_sizeac                     0 non-null float64
# pbi_rate                       0 non-null float64
# new_constr                     27106 non-null float64
# effic_1                        0 non-null float64
# cust_county                    0 non-null float64
# tracking                       1930 non-null float64
# inv_model_clean                0 non-null float64
# mod_cost_real                  0 non-null float64
# inv_cost_real                  0 non-null float64
# bos_powerclerk_real            0 non-null float64
# permitting_real                0 non-null float64
# 3rdparty                       306993 non-null float64
# dtypes: float64(59), object(22)
# memory usage: 630.5+ MB

# %%
# Getting rid of columns where there's no data

# first getting a list all the column names where there's no data.

non_null_cols = [col for col in df.columns if df[col].notnull().sum() != 0]

# %%
# limiting the dataframe to just non-null columns

df = df[non_null_cols]

# %%
# it worked!

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020303 entries, 0 to 1020302
# Data columns (total 39 columns):
# state                          1020303 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           797958 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      224036 non-null object
# zipcode                        1020298 non-null float64
# install_type                   977722 non-null object
# installer                      702324 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           998765 non-null object
# lbnl_tts_version_year          797958 non-null float64
# lbnl_tts                       797958 non-null object
# city                           798736 non-null object
# utility_clean                  792720 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         998652 non-null object
# annual_PV_prod                 780969 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manuf2_clean                   231607 non-null object
# manuf3_clean                   209653 non-null object
# manuf1_clean                   201121 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# year                           68 non-null object
# pbi_length                     5427 non-null float64
# utility                        2117 non-null object
# bipv_3                         5255 non-null float64
# bipv_2                         5255 non-null float64
# bipv_1                         5255 non-null float64
# new_constr                     27106 non-null float64
# tracking                       1930 non-null float64
# 3rdparty                       306993 non-null float64
# dtypes: float64(17), object(22)
# memory usage: 303.6+ MB

# %% [markdown]
# ## Incentive Program Names
#
#
# These are probably pretty important to determining cost, so let's see if we can find some trend to impute it.

# %%
# There are a bunch of these incentive programs, which almost definitely have an influence on people's
# eventual cost of solar.

df['incentive_prog_names'].value_counts()
# Out:
# California Public Utilities Commission (Non-CSI Net Metered Systems)          260940
# California Public Utilities Commission (California Solar Initiative)          148988
# New York State Energy Research and Development Authority                       44012
# Arizona Public Service                                                         40647
# Massachusetts Clean Energy Center                                              36810
# New Jersey Board of Public Utilities (SREC Program)                            34168
# California Energy Commission (Emerging Renewables Program)                     27952
# Massachusetts Department of Energy Resources                                   24828
# Los Angeles Department of Water & Power                                        19757
# California Energy Commission (New Solar Homes Partnership)                     17286
# Connecticut Clean Energy Finance and Investment Authority                      15746
# Salt River Project                                                             15275
# NV Energy                                                                      14530
# Sacramento Municipal Utility District                                          11694
# Tucson Electric Power                                                          10921
# New Jersey Board of Public Utilities (CORE & REIP Programs)                     8081
# Maryland Energy Administration                                                  7472
# Pennsylvania Department of Environmental Protection                             7033
# New Mexico Energy, Minerals and Natural Resources Department                    6527
# Austin Energy                                                                   4688
# Ameren                                                                          3650
# CPS Energy                                                                      3284
# Delaware Department of Natural Resources and Environmental Control              3022
# New Hampshire Public Utilities Commission                                       2909
# Imperial Irrigation District                                                    2333
# Wisconsin Focus on Energy                                                       2106
# Ohio Public Utilities Commission                                                1918
# UniSource Energy Services                                                       1827
# Oregon Department of Energy                                                     1637
# Kansas City Power & Light                                                       1517
#                                                                                ...
# Minnesota Department of Commerce                                                1027
# Washington, DC Public Service Commission                                         953
# Oncor Electric Delivery Company                                                  904
# Washington, DC Department of Energy & Environment                                848
# City of Palo Alto Utilities                                                      823
# Pacific Power                                                                    698
# Efficiency Maine                                                                 551
# California Public Utilities Commission (Self-Generation Incentive Program)       544
# Rhode Island Office of Energy Resources                                          541
# Gainesville Regional Utilities                                                   478
# Mohave Electric Cooperative                                                      449
# Rocky Mountain Power                                                             430
# El Paso Electric                                                                 368
# Orlando Utilities Commission                                                     202
# Pennsylvania Sustainable Development Fund                                        200
# Pacific Power (California Center for Sustainable Energy)                         181
# Rebuild a Greener San Diego (California Center for Sustainable Energy)           152
# Texas Central Company                                                            146
# Navopache Electric Cooperative                                                   140
# Graham County Electric Cooperative                                               129
# Arkansas State Energy Office                                                      98
# Bear Valley Electric (California Center for Sustainable Energy)                   78
# Texas North Company                                                               74
# Entergy                                                                           57
# Southwestern Electric Power Company                                               39
# Texas New Mexico Power Company                                                    23
# Duncan Valley Electric Cooperative                                                 5
# Ajo Improvement Company                                                            3
# Morenci Water and Electric                                                         3
# Sharyland Utilities                                                                2
# Name: incentive_prog_names, dtype: int64

# %%
# let's look at average cost_per_watt for these different commisions:

import seaborn as sns

# %matplotlib inline

# %%
# There's definitely some variance around this, and it looks like within each of these the variance or price
# is pretty tight.

fig = plt.figure(figsize=(6,10))

sns.barplot(x=df["cost_per_watt"], y=df["incentive_prog_names"], orient = 'h')

# %%
# Either values where the incentive is plank means they didn't have an incentive program, or that 
# it isn't listed.  If it's the latter, maybe we can impute it.

null_incentive_state = df.loc[df['incentive_prog_names'].isnull(), :].groupby("state").size()

# %%
# looking at proportion by state with no incentive program compared to with incentive program may provide some clues

zip(null_incentive_state.sort_values(ascending=False).index, sorted(null_incentive_state/sum(null_incentive_state), reverse=True))
# Out:
# [('CA', 0.60616159571836559),
#  ('AZ', 0.077977917200746594),
#  ('MA', 0.043999190447277882),
#  ('NJ', 0.03956014302098091),
#  ('CT', 0.03551687692549866),
#  ('NY', 0.031374665497312736),
#  ('TX', 0.021295734106905936),
#  ('PA', 0.018619712608783649),
#  ('MD', 0.017670736917852887),
#  ('CO', 0.01171152938001754),
#  ('HI', 0.010452225145607051),
#  ('DE', 0.0094177966673412942),
#  ('OR', 0.0087476669140299987),
#  ('NM', 0.0082259551597742252),
#  ('VT', 0.0073849198317929342),
#  ('NV', 0.0068272279565540035),
#  ('DC', 0.0067237851087274285),
#  ('WI', 0.0054644808743169399),
#  ('FL', 0.0049292765746924826),
#  ('IN', 0.0035620319773325237),
#  ('TN', 0.002703006588859655),
#  ('NH', 0.0026625289527536038),
#  ('MN', 0.0024421507117317683),
#  ('UT', 0.0017315433223144213),
#  ('IL', 0.0016730756257167915),
#  ('LA', 0.0015516427173986372),
#  ('MO', 0.0015156625964154805),
#  ('OH', 0.0014706874451865344),
#  ('MI', 0.0011828464773212799),
#  ('WA', 0.00093998066068497156),
#  ('IA', 0.00092648811531628771),
#  ('WY', 0.00070610987429445228),
#  ('ME', 0.00067912478355708469),
#  ('AR', 0.00063414963232813872),
#  ('SC', 0.00059367199622208729),
#  ('WV', 0.00041377139130630328),
#  ('NC', 0.00033731363421709507),
#  ('MS', 0.00031932357372551663),
#  ('MT', 0.00027434842249657066),
#  ('GA', 0.00023836830151341385),
#  ('VA', 0.00022487575614473003),
#  ('ID', 0.00019339315028446782),
#  ('RI', 0.00018889563516157323),
#  ('AL', 0.00014392048393262722),
#  ('KY', 0.00013942296880973263),
#  ('KS', 0.00012593042344104881),
#  ('AK', 9.894533270368121e-05),
#  ('NE', 7.645775708920821e-05),
#  ('SD', 7.1960241966313612e-05),
#  ('OK', 4.4975151228946008e-05),
#  ('OH ', 2.2487575614473004e-05),
#  ('PR', 1.7990060491578403e-05),
#  ('ND', 1.3492545368683802e-05),
#  ('MD ', 8.9950302457892015e-06),
#  ('PA ', 8.9950302457892015e-06)]

# %%
notnull_incentive_state = df.loc[df['incentive_prog_names'].notnull(), :].groupby("state").size()

zip(notnull_incentive_state.sort_values(ascending=False).index, sorted(notnull_incentive_state/sum(notnull_incentive_state), reverse=True))
# Out:
# [('CA', 0.61662393258793069),
#  ('AZ', 0.090257883246987941),
#  ('MA', 0.077244667012549534),
#  ('NY', 0.05515578514157387),
#  ('NJ', 0.052946395674960338),
#  ('CT', 0.019732868145942519),
#  ('NV', 0.01820897841741044),
#  ('TX', 0.012011910401299317),
#  ('MD', 0.0093639013582168477),
#  ('PA', 0.0090643868474280607),
#  ('NM', 0.0081796285017507186),
#  ('MO', 0.0064752781474714206),
#  ('DE', 0.0037871667431117928),
#  ('NH', 0.0036455552798518218),
#  ('OR', 0.0029262191744427652),
#  ('WI', 0.0026392366515530894),
#  ('OH', 0.0024036352790497745),
#  ('FL', 0.0023660393153524372),
#  ('DC', 0.0022570110206301583),
#  ('IL', 0.0013923038555913971),
#  ('MN', 0.0012870351572388521),
#  ('ME', 0.00069051253324109788),
#  ('RI', 0.00067798054534198545),
#  ('UT', 0.0005388754796618368),
#  ('AR', 0.00012281348141130236)]

# %%
# looks like some states don't even show up, probably safe to assume that those states just don't have 
# incentive programs.

# given that, it seems like it may be difficult to distingush between cases where there was no incentive program
# available and where it was unreported.

df['incentive_prog_names'].fillna("no_incentive_program", inplace=True)

# %% [markdown]
# ## Utility_Clean
#
# I have a hunch that this is going to be heavily linked to states and/or counties, we can probably impute this by grabbing the mode value from each state or county.  Let's explore.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020303 entries, 0 to 1020302
# Data columns (total 39 columns):
# state                          1020303 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020303 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      224036 non-null object
# zipcode                        1020298 non-null float64
# install_type                   977722 non-null object
# installer                      702324 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           998765 non-null object
# lbnl_tts_version_year          797958 non-null float64
# lbnl_tts                       797958 non-null object
# city                           798736 non-null object
# utility_clean                  792720 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         998652 non-null object
# annual_PV_prod                 780969 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manuf2_clean                   231607 non-null object
# manuf3_clean                   209653 non-null object
# manuf1_clean                   201121 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# year                           68 non-null object
# pbi_length                     5427 non-null float64
# utility                        2117 non-null object
# bipv_3                         5255 non-null float64
# bipv_2                         5255 non-null float64
# bipv_1                         5255 non-null float64
# new_constr                     27106 non-null float64
# tracking                       1930 non-null float64
# 3rdparty                       306993 non-null float64
# dtypes: float64(17), object(22)
# memory usage: 303.6+ MB

# %%
# We can already see that there's quite a bit of deviation within states, for instance a lof of CA is on 
# Los Angeles Department of Water & Power, and a lot is on Pacific Gas & Electric Co, maybe county will help.

df.groupby(['state', 'utility_clean']).size()
# Out:
# state  utility_clean
# AR     Carroll Electric Coop Corp                         1
#        Carroll Electric Coop Corp - (AR)                  1
#        Entergy Arkansas Inc                              61
#        Oklahoma Gas & Electric Co                         3
#        Southwestern Electric Power Co                    32
# AZ     Ajo Improvement Company                            3
#        Arizona Public Service                         40647
#        Duncan Valley Electric Cooperative                 5
#        Graham County Electric Cooperative               129
#        Mohave Electric Cooperative                      449
#        Morenci Water and Electric                         3
#        Navopache Electric Cooperative                   140
#        Salt River Project                             15275
#        Sulphur Springs Valley Electric Cooperative     1266
#        Trico Electric Cooperative                      1357
#        Tucson Electric Power                          10921
#        UniSource Energy Services                       1827
# CA     Bear Valley Electric Service                      96
#        Burbank Water and Power                            5
#        City of Palo Alto Utilities                      823
#        City of Riverside                                  2
#        City of San Francisco                              3
#        Constellation                                      1
#        DIRECT ACCESS - APS                                1
#        Hetch Hetchy                                       4
#        Imperial Irrigation District                    2334
#        LADWP                                              6
#        Lodi Electric                                      2
#        Los Angeles Department of Water & Power        19757
#        Pacific Gas & Electric Co                       2664
#                                                       ...
# PA     PPL Electric Utilities                          2433
#        PPL Electric Utilities Corp                      381
#        Penn Power                                        38
#        PennPwr                                            1
#        Pennsylvania Electric Co                          54
#        Pennsylvania Power Co                              2
#        UGI                                               55
#        Wellsboro                                          3
#        West Penn Power Co                                39
#        West Penn Power Company                          110
# RI     National Grid                                    541
# TX     Austin Energy                                   4688
#        CPS Energy                                      3284
#        El Paso Electric                                 368
#        Entergy                                           57
#        Oncor Electric Delivery Company                  904
#        Sharyland Utilities                                2
#        Southwestern Electric Power Company               39
#        Texas Central Company                            146
#        Texas New Mexico Power Company                    23
#        Texas North Company                               74
# UT     Rocky Mountain Power                             430
# WI     Barron Electric Coop                              13
#        Northern States Power Co                         134
#        Northern States Power Co - Wisconsin              26
#        Superior Water and Light Co                        6
#        Superior Water, Light and Power Co                 1
#        Wisconsin Electric Power Co                     1231
#        Wisconsin Power & Light Co                       343
#        Wisconsin Public Service Corp                    172
# dtype: int64

# %%
# this looks quite a bit better, looks like in most counties there's only one or maybe 2 utilities that
# people are on.

county_utilities = pd.DataFrame(df.groupby(['state', 'county', 'utility_clean']).size()).reset_index()
county_utilities
# Out:
#      state        county                         utility_clean   0
# 0       AR        Benton        Southwestern Electric Power Co   6
# 1       AR         Boone                  Entergy Arkansas Inc   3
# 2       AR       Carroll                  Entergy Arkansas Inc   4
# 3       AR        Chicot                  Entergy Arkansas Inc   1
# 4       AR      Crawford            Oklahoma Gas & Electric Co   2
# 5       AR      Faulkner                  Entergy Arkansas Inc   3
# 6       AR      Franklin            Oklahoma Gas & Electric Co   1
# 7       AR       Garland                  Entergy Arkansas Inc   4
# 8       AR         Grant                  Entergy Arkansas Inc   2
# 9       AR     Hempstead                  Entergy Arkansas Inc   1
# 10      AR  Independence                  Entergy Arkansas Inc   1
# 11      AR       Lincoln                  Entergy Arkansas Inc   1
# 12      AR         Logan                  Entergy Arkansas Inc   2
# 13      AR       Madison            Carroll Electric Coop Corp   1
# 14      AR       Madison     Carroll Electric Coop Corp - (AR)   1
# 15      AR        Marion                  Entergy Arkansas Inc   1
# 16      AR        Newton                  Entergy Arkansas Inc   4
# 17      AR          Pike                  Entergy Arkansas Inc   1
# 18      AR          Polk        Southwestern Electric Power Co   6
# 19      AR          Pope                  Entergy Arkansas Inc   1
# 20      AR       Pulaski                  Entergy Arkansas Inc  13
# 21      AR        Saline                  Entergy Arkansas Inc  14
# 22      AR        Searcy                  Entergy Arkansas Inc   2
# 23      AR     Sebastian        Southwestern Electric Power Co   2
# 24      AR    St Francis                  Entergy Arkansas Inc   1
# 25      AR         Union                  Entergy Arkansas Inc   1
# 26      AR     Van Buren                  Entergy Arkansas Inc   1
# 27      AR    Washington        Southwestern Electric Power Co  18
# 28      AZ        Apache                Arizona Public Service  10
# 29      AZ        Apache        Navopache Electric Cooperative  60
# ...    ...           ...                                   ...  ..
# 1922    WI     Outagamie           Wisconsin Electric Power Co  62
# 1923    WI       Ozaukee           Wisconsin Electric Power Co  29
# 1924    WI         Pepin              Northern States Power Co   3
# 1925    WI        Pierce              Northern States Power Co  24
# 1926    WI        Pierce  Northern States Power Co - Wisconsin   6
# 1927    WI          Polk              Northern States Power Co  12
# 1928    WI          Polk  Northern States Power Co - Wisconsin   1
# 1929    WI       Portage            Wisconsin Power & Light Co  30
# 1930    WI       Portage         Wisconsin Public Service Corp  79
# 1931    WI         Price              Northern States Power Co   6
# 1932    WI        Racine           Wisconsin Electric Power Co  30
# 1933    WI      Richland            Wisconsin Power & Light Co  16
# 1934    WI          Rock           Wisconsin Electric Power Co  26
# 1935    WI          Sauk            Wisconsin Power & Light Co  57
# 1936    WI        Sawyer              Northern States Power Co   5
# 1937    WI       Shawano           Wisconsin Electric Power Co   7
# 1938    WI     Sheboygan           Wisconsin Electric Power Co  30
# 1939    WI      St Croix              Northern States Power Co   5
# 1940    WI        Taylor              Northern States Power Co   8
# 1941    WI   Trempealeau              Northern States Power Co   2
# 1942    WI        Vernon            Wisconsin Power & Light Co  29
# 1943    WI         Vilas           Wisconsin Electric Power Co  10
# 1944    WI      Walworth           Wisconsin Electric Power Co  57
# 1945    WI      Washburn              Northern States Power Co   2
# 1946    WI    Washington           Wisconsin Electric Power Co  29
# 1947    WI      Waukesha           Wisconsin Electric Power Co  86
# 1948    WI       Waupaca           Wisconsin Electric Power Co  51
# 1949    WI      Waushara           Wisconsin Electric Power Co  12
# 1950    WI     Winnebago           Wisconsin Electric Power Co  32
# 1951    WI          Wood            Wisconsin Power & Light Co  34
#
# [1952 rows x 4 columns]

# %%
# Looking at california, looks like this is pretty robust, I'm also noticing that there's a ton of double labled stuff
# let's also change 'Pacific Gas & Electric Co' to "Pacific Gas & Electric Company"

county_utilities[county_utilities['state'] == "CA"]
# Out:
#     state        county                            utility_clean      0
# 71     CA       Alameda                Pacific Gas & Electric Co    191
# 72     CA       Alameda           Pacific Gas & Electric Company  16285
# 73     CA       Alameda                          Port of Oakland      1
# 74     CA       Alameda               Southern California Edison      5
# 75     CA        Amador                Pacific Gas & Electric Co      1
# 76     CA        Amador           Pacific Gas & Electric Company    663
# 77     CA         Butte                Pacific Gas & Electric Co     76
# 78     CA         Butte           Pacific Gas & Electric Company   5383
# 79     CA         Butte               Southern California Edison      1
# 80     CA     Calaveras           Pacific Gas & Electric Company   1047
# 81     CA        Colusa           Pacific Gas & Electric Company    460
# 82     CA  Contra Costa                Pacific Gas & Electric Co    181
# 83     CA  Contra Costa           Pacific Gas & Electric Company  20441
# 84     CA  Contra Costa               Southern California Edison      3
# 85     CA     Del Norte            Pacific Power & Light Company      8
# 86     CA     El Dorado           Pacific Gas & Electric Company   5541
# 87     CA     El Dorado    Sacramento Municipal Utility District      1
# 88     CA     El Dorado         San Diego Gas & Electric Company      1
# 89     CA        Fresno                      DIRECT ACCESS - APS      1
# 90     CA        Fresno                Pacific Gas & Electric Co    251
# 91     CA        Fresno           Pacific Gas & Electric Company  20245
# 92     CA        Fresno         San Diego Gas & Electric Company      1
# 93     CA        Fresno               Southern California Edison     14
# 94     CA        Fresno            Southern California Edison Co     45
# 95     CA         Glenn                Pacific Gas & Electric Co     75
# 96     CA         Glenn           Pacific Gas & Electric Company    955
# 97     CA      Humboldt                Pacific Gas & Electric Co     41
# 98     CA      Humboldt           Pacific Gas & Electric Company    795
# 99     CA      Humboldt         San Diego Gas & Electric Company      1
# 100    CA      Humboldt               Southern California Edison      3
# ..    ...           ...                                      ...    ...
# 222    CA        Solano                Pacific Gas & Electric Co     15
# 223    CA        Solano           Pacific Gas & Electric Company   7570
# 224    CA        Solano               Southern California Edison      2
# 225    CA        Sonoma                Pacific Gas & Electric Co     54
# 226    CA        Sonoma           Pacific Gas & Electric Company   9657
# 227    CA    Stanislaus                Pacific Gas & Electric Co      1
# 228    CA    Stanislaus           Pacific Gas & Electric Company   1324
# 229    CA        Sutter                Pacific Gas & Electric Co     16
# 230    CA        Sutter           Pacific Gas & Electric Company   2376
# 231    CA        Sutter               Southern California Edison      1
# 232    CA        Tehama                Pacific Gas & Electric Co     99
# 233    CA        Tehama           Pacific Gas & Electric Company   1611
# 234    CA        Tehama               Southern California Edison      1
# 235    CA       Trinity           Pacific Gas & Electric Company     11
# 236    CA        Tulare                Pacific Gas & Electric Co    293
# 237    CA        Tulare           Pacific Gas & Electric Company    555
# 238    CA        Tulare         San Diego Gas & Electric Company      1
# 239    CA        Tulare               Southern California Edison   6803
# 240    CA        Tulare            Southern California Edison Co    243
# 241    CA      Tuolumne           Pacific Gas & Electric Company    596
# 242    CA       Ventura  Los Angeles Department of Water & Power      1
# 243    CA       Ventura           Pacific Gas & Electric Company      7
# 244    CA       Ventura         San Diego Gas & Electric Company      1
# 245    CA       Ventura               Southern California Edison  11672
# 246    CA       Ventura            Southern California Edison Co    211
# 247    CA          Yolo                Pacific Gas & Electric Co     24
# 248    CA          Yolo           Pacific Gas & Electric Company   5572
# 249    CA          Yolo    Sacramento Municipal Utility District      1
# 250    CA          Yuba                Pacific Gas & Electric Co      3
# 251    CA          Yuba           Pacific Gas & Electric Company   1466
#
# [181 rows x 4 columns]

# %%
# changing some misnamed PG&E values

df.loc[df['utility_clean'] == "Pacific Gas & Electric Co", 'utility_clean'] = "Pacific Gas & Electric Company"

# %%
mode(df.head(100).utility_clean)[0][0]
# Out:
# 'Austin Energy'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020303 entries, 0 to 1020302
# Data columns (total 39 columns):
# state                          1020303 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020303 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null object
# appraised                      226700 non-null object
# zipcode                        1020298 non-null object
# install_type                   977850 non-null object
# installer                      702336 non-null object
# cost_per_watt                  762737 non-null object
# cost                           998765 non-null object
# lbnl_tts_version_year          797958 non-null object
# lbnl_tts                       797958 non-null object
# city                           798736 non-null object
# utility_clean                  792720 non-null object
# tech_1                         583565 non-null object
# model1_clean                   583565 non-null object
# county                         998652 non-null object
# annual_PV_prod                 781123 non-null object
# annual_insolation              781123 non-null object
# rebate                         388546 non-null object
# sales_tax_cost                 355309 non-null object
# tilt1                          386029 non-null object
# tracking_type                  528722 non-null object
# azimuth1                       365945 non-null object
# manuf2_clean                   234252 non-null object
# manuf3_clean                   212298 non-null object
# manuf1_clean                   203766 non-null object
# inv_man_clean                  52595 non-null object
# reported_annual_energy_prod    207093 non-null object
# year                           2732 non-null object
# pbi_length                     8091 non-null object
# utility                        4781 non-null object
# bipv_3                         7919 non-null object
# bipv_2                         7919 non-null object
# bipv_1                         7919 non-null object
# new_constr                     29766 non-null object
# tracking                       4594 non-null object
# 3rdparty                       309657 non-null object
# dtypes: object(39)
# memory usage: 303.6+ MB

# %%
# I'm just going to go ahead and impute the utility based on the mode for teh state

# %%
import sqlite3

conn = sqlite3.Connection("./capstone.sqlite")
conn.text_factory = str

df.to_sql('open_pv_clean', con=conn, if_exists='replace')

# %%
# cleaning up some fucked up shit with state entries.

df.loc[df['state'] == 'PA ', 'state'] = 'PA'
df.loc[df['state'] == 'MD ', 'state'] = 'MD'
df.loc[df['state'] == 'OH ', 'state'] = "OH"

# %%
# Looks like there are a few states where there's no listing.  let's just fill the states where there are some
# utility listings, and fill the other ones with "no utility listed"

for state in states:
    print state, "non_nulls: ", df.loc[df['state'] == state, 'utility_clean'].notnull().sum()
    print state, "nulls: ", df.loc[df['state'] == state, 'utility_clean'].isnull().sum()
    print "\n"
# Out:
# TX non_nulls:  9585
# TX nulls:  4735
#
#
# CA non_nulls:  492026
# CA nulls:  134791
#
#
# VA non_nulls:  0
# VA nulls:  50
#
#
# WI non_nulls:  1926
# WI nulls:  1395
#
#
# CO non_nulls:  0
# CO nulls:  2604
#
#
# MD non_nulls:  6266
# MD nulls:  5137
#
#
# OH non_nulls:  43
# OH nulls:  2207
#
#
# FL non_nulls:  1821
# FL nulls:  1163
#
#
# NY non_nulls:  44012
# NY nulls:  6976
#
#
# MA non_nulls:  61635
# MA nulls:  9786
#
#
# DE non_nulls:  3022
# DE nulls:  2094
#
#
# WA non_nulls:  0
# WA nulls:  209
#
#
# IA non_nulls:  0
# IA nulls:  206
#
#
# MS non_nulls:  0
# MS nulls:  71
#
#
# IN non_nulls:  0
# IN nulls:  792
#
#
# HI non_nulls:  0
# HI nulls:  2324
#
#
# KS non_nulls:  0
# KS nulls:  28
#
#
# GA non_nulls:  0
# GA nulls:  53
#
#
# ME non_nulls:  519
# ME nulls:  183
#
#
# NH non_nulls:  2893
# NH nulls:  608
#
#
# CT non_nulls:  15727
# CT nulls:  7916
#
#
# IL non_nulls:  1101
# IL nulls:  382
#
#
# VT non_nulls:  0
# VT nulls:  1642
#
#
# NM non_nulls:  6526
# NM nulls:  1830
#
#
# AL non_nulls:  0
# AL nulls:  32
#
#
# MO non_nulls:  5167
# MO nulls:  337
#
#
# KY non_nulls:  0
# KY nulls:  31
#
#
# NJ non_nulls:  42246
# NJ nulls:  8799
#
#
# AK non_nulls:  0
# AK nulls:  22
#
#
# MN non_nulls:  1027
# MN nulls:  543
#
#
# MI non_nulls:  0
# MI nulls:  263
#
#
# PA non_nulls:  7233
# PA nulls:  4142
#
#
# MT non_nulls:  0
# MT nulls:  61
#
#
# ID non_nulls:  0
# ID nulls:  43
#
#
# SD non_nulls:  16
# SD nulls:  0
#
#
# UT non_nulls:  430
# UT nulls:  385
#
#
# ND non_nulls:  3
# ND nulls:  0
#
#
# RI non_nulls:  541
# RI nulls:  42
#
#
# NE non_nulls:  0
# NE nulls:  17
#
#
# AZ non_nulls:  72022
# AZ nulls:  17338
#
#
# TN non_nulls:  0
# TN nulls:  601
#
#
# DC non_nulls:  0
# DC nulls:  3296
#
#
# OR non_nulls:  2324
# OR nulls:  1956
#
#
# LA non_nulls:  0
# LA nulls:  345
#
#
# AR non_nulls:  98
# AR nulls:  141
#
#
# WV non_nulls:  0
# WV nulls:  92
#
#
# OK non_nulls:  10
# OK nulls:  0
#
#
# WY non_nulls:  0
# WY nulls:  157
#
#
# NC non_nulls:  0
# NC nulls:  75
#
#
# NV non_nulls:  14530
# NV nulls:  1518
#
#
# SC non_nulls:  0
# SC nulls:  132
#
#
# PR non_nulls:  4
# PR nulls:  0

# %%
states = list(df.state.unique())

for state in states:
    non_nulls = df.loc[df['state'] == state, 'utility_clean'].notnull().sum()
    if non_nulls == 0:
        df.loc[df['state'] == state, 'utility_clean'] = "no utility listed"
    else:
        mode_utility = df.loc[df['state'] == state, 'utility_clean'].value_counts().index[0]
        mask = (df['state'] == state) & (df['utility_clean'].isnull())
        df.loc[mask, 'utility_clean'] = mode_utility
        
print df['utility_clean'].isnull().sum()
# Out:
# 0

# %%
df.loc[df['state'] == 'CA', 'utility_clean'].isnull().sum()
# Out:
# 0

# %%
df.groupby(['state', 'utility_clean']).size()
# Out:
# state  utility_clean
# AK     no utility listed                                 22
# AL     no utility listed                                 32
# AR     Carroll Electric Coop Corp                         1
#        Carroll Electric Coop Corp - (AR)                  1
#        Entergy Arkansas Inc                             202
#        Oklahoma Gas & Electric Co                         3
#        Southwestern Electric Power Co                    32
# AZ     Ajo Improvement Company                            3
#        Arizona Public Service                         57985
#        Duncan Valley Electric Cooperative                 5
#        Graham County Electric Cooperative               129
#        Mohave Electric Cooperative                      449
#        Morenci Water and Electric                         3
#        Navopache Electric Cooperative                   140
#        Salt River Project                             15275
#        Sulphur Springs Valley Electric Cooperative     1266
#        Trico Electric Cooperative                      1357
#        Tucson Electric Power                          10921
#        UniSource Energy Services                       1827
# CA     Bear Valley Electric Service                      96
#        Burbank Water and Power                            5
#        City of Palo Alto Utilities                      823
#        City of Riverside                                  2
#        City of San Francisco                              3
#        Constellation                                      1
#        DIRECT ACCESS - APS                                1
#        Hetch Hetchy                                       4
#        Imperial Irrigation District                    2334
#        LADWP                                              6
#        Lodi Electric                                      2
#                                                       ...
# PA     no utility listed                                  2
# PR     no utility listed                                  4
# RI     National Grid                                    583
# SC     no utility listed                                132
# SD     no utility listed                                 16
# TN     no utility listed                                601
# TX     Austin Energy                                   9423
#        CPS Energy                                      3284
#        El Paso Electric                                 368
#        Entergy                                           57
#        Oncor Electric Delivery Company                  904
#        Sharyland Utilities                                2
#        Southwestern Electric Power Company               39
#        Texas Central Company                            146
#        Texas New Mexico Power Company                    23
#        Texas North Company                               74
# UT     Rocky Mountain Power                             815
# VA     no utility listed                                 50
# VT     no utility listed                               1642
# WA     no utility listed                                209
# WI     Barron Electric Coop                              13
#        Northern States Power Co                         134
#        Northern States Power Co - Wisconsin              26
#        Superior Water and Light Co                        6
#        Superior Water, Light and Power Co                 1
#        Wisconsin Electric Power Co                     2626
#        Wisconsin Power & Light Co                       343
#        Wisconsin Public Service Corp                    172
# WV     no utility listed                                 92
# WY     no utility listed                                157
# dtype: int64

# %%
# FUCKING FINALLY.

# saving this to the db
df.to_sql("open_pv_clean", con=conn, if_exists="replace")

# %% [markdown]
# # Install Type

# %%
df = pd.read_sql("SELECT * FROM open_pv_clean", con=conn)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020303 entries, 0 to 1020302
# Data columns (total 39 columns):
# state                          1020303 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020303 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      224036 non-null object
# zipcode                        1020298 non-null float64
# install_type                   977722 non-null object
# installer                      702324 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           998765 non-null object
# lbnl_tts_version_year          797958 non-null float64
# lbnl_tts                       797958 non-null object
# city                           798736 non-null object
# utility_clean                  1020303 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         998652 non-null object
# annual_PV_prod                 780969 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manuf2_clean                   231607 non-null object
# manuf3_clean                   209653 non-null object
# manuf1_clean                   201121 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# year                           68 non-null object
# pbi_length                     5427 non-null float64
# utility                        2117 non-null object
# bipv_3                         5255 non-null float64
# bipv_2                         5255 non-null float64
# bipv_1                         5255 non-null float64
# new_constr                     27106 non-null float64
# tracking                       1930 non-null float64
# 3rdparty                       306993 non-null float64
# dtypes: float64(17), object(22)
# memory usage: 303.6+ MB

# %%
# looks like there's a lot of improperly named stuff here.  if we just make them all lower case that will help.

# we can also probably safely impute the empty values with residential.  Maybe there's some connection between
# size and type though, let's look at a box plot for that.

df.install_type.value_counts()
# Out:
# residential                    728661
# Residential                    179166
# commercial                      24470
# Unknown                         15770
# Commercial                      11868
# unknown                          4034
# government                       3721
# nonprofit                        3003
# Government                       2024
# educational                      1703
# Nonprofit                        1216
# Educational                       709
# Customer                          371
# education                         290
# Agricultural                      267
# Utility                           138
# agricultural                      124
# utility                            92
# Institutional                      29
# Commercial - Other                 16
# Gov't/NP                           11
# Public                             11
# agriculture                         5
# Residential/SF                      5
# public                              5
# Nonresidential                      3
# Commercial - Small Business         2
# Small Business                      2
# Not Stated                          2
# Municipal                           1
# Commercial - Agriculture            1
# Commercial - Builders               1
# Commerical                          1
# Name: install_type, dtype: int64

# %%
# setting it all to lower case

df['install_type'] = [install.lower() for install in df['install_type'].astype(str)]

# %%
# consolidating commercial

df['install_type'] = ['commercial' if "commercial" in install else install for install in df['install_type']]

# %%
df['install_type'] = ['educational' if "educat" in install else
                      'commercial' if 'commer' in install else
                      'public' if "gov't" in install else
                      'residential' if '/sf' in install else
                      'agricultural' if 'agricu' in install else
                      'public' if install == 'municipal' 
                      else install for install in df['install_type']]

# %%
df['install_type'].value_counts()
# Out:
# residential       907832
# nan                42581
# commercial         36359
# unknown            19804
# government          5745
# nonprofit           4219
# educational         2702
# agricultural         396
# customer             371
# utility              230
# institutional         29
# public                28
# nonresidential         3
# small business         2
# not stated             2
# Name: install_type, dtype: int64

# %%
# let's make some of the rando one's nan and get rid of small-business

nan_labels = ['nonresidential', 'not stated', 'unknown', 'customer']

df['install_type'] = ['nan' if install in nan_labels else
                     'commercial' if 'small business' in install else
                     install for install in df['install_type']]

# %%
# residential seriously dominates, but maybe there's some big trend we can use to imput the nan

df['install_type'].value_counts()
# Out:
# residential      907832
# nan               62761
# commercial        36361
# government         5745
# nonprofit          4219
# educational        2702
# agricultural        396
# utility             230
# institutional        29
# public               28
# Name: install_type, dtype: int64

# %%
df['install_type'] = [np.nan if install == 'nan' else install for install in df['install_type']]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
fig = plt.figure(figsize=(10,6))

# kind of hard to get anything out of this, also wtf nan and residential are just not even showing up.

data = [df.loc[df['install_type'] == install, 'size_kw'] for install in df['install_type'].unique()]
plt.boxplot(data, labels = df['install_type'].unique())
plt.ylim(0,20000)
# Out:
# (0, 20000)

# %%
fig = plt.figure(figsize=(6,10))
sns.barplot(y=df['install_type'], x=df['size_kw'], orient='h')

# %%
# okay looks like anything larger than the max government one we can for sure say is utility, that's interesting
# we have to ge rid of utility to see anything else.

utility_cutoff = df.loc[df['install_type'] == 'utility', 'size_kw'].max()

# %%
utility_cutoff
# Out:
# 333000.0

# %%
fig = plt.figure(figsize=(6,10))
sns.barplot(y=df.loc[df['install_type'] != 'utility', 'install_type'],
            x=df.loc[df['install_type'] != 'utility','size_kw'], orient='h')

# %%
df.install_type.value_counts()
# Out:
# residential      907832
# commercial        36361
# government         5745
# nonprofit          4219
# educational        2702
# agricultural        396
# utility             230
# institutional        29
# public               28
# Name: install_type, dtype: int64

# %%
# I'll just make cutoffs for utility because it's such a standout, then residential, commercial, and government.

# utility if > utility cuttoff
# governement if <= utility cutoff and > education max
# commercial if <= education max and > institutional max
# residuential if <= instutional max

utility_cutoff = df.loc[df['install_type'] == 'utility', 'size_kw'].max()
education_max = df.loc[df['install_type'] == 'educational', 'size_kw'].max()
instit_max = df.loc[df['install_type'] == 'institutional', 'size_kw'].max()


def install_filler(row):
    # this function will go through every row and fill in null values for install_type with a value based on the 
    # size of the installation
    
    # check if row is null.
    if row['install_type'] == np.nan:
        
        # check if there's a size we can go off of.
        if row['size_kw'] == np.nan:
            
            # compare size
            if row['size_kw'] > utility_cutoff:
                row['install_type'] = 'utility'
            elif row['size_kw'] <= utility_cutoff and row['size_kw'] > education_max:
                row['install_type'] = 'government'
            elif row['size_kw'] <= education_max and row['size_kw'] > instit_max:
                row['install_type'] = 'commercial'
            else:
                row['install_type'] = 'residential'
                
    return row

# %%
df = df.apply(install_filler, axis=1)

# %%
# forgot to fill ones that don't have a size with residential.

df.install_type.isnull().sum()
# Out:
# 62761

# %%
df.install_type.fillna(value='residential', inplace=True)

# %%
df.install_type.isnull().sum()
# Out:
# 0

# %%
# we did it.

df.install_type.value_counts()
# Out:
# residential      970593
# commercial        36361
# government         5745
# nonprofit          4219
# educational        2702
# agricultural        396
# utility             230
# institutional        29
# public               28
# Name: install_type, dtype: int64

# %%
del(df['index'])

# %%
# saving to the database.

df.to_sql('open_pv_clean_backup', con=conn, if_exists="replace")

# %%
df.to_sql('open_pv_clean', con=conn, if_exists="replace")

# %% [markdown]
# # Appraised

# %%
# looks like it's just one value, seems safe to assume that it's just a binary thing, so we can just leave it blank

df.appraised.value_counts()
# Out:
# True    224036
# Name: appraised, dtype: int64

# %%
# I'm going to change this to a 1 / 0 ohe situation.

df.appraised.fillna(0, inplace=True)

# %%
mask = df.appraised == True
df.loc[mask, 'appraised'] = 1

# %%
df.appraised = pd.to_numeric(df.appraised)

# %% [markdown]
# # Zipcode and address information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020303 entries, 0 to 1020302
# Data columns (total 39 columns):
# state                          1020303 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020303 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      224036 non-null object
# zipcode                        1020298 non-null float64
# install_type                   1020303 non-null object
# installer                      702324 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           998765 non-null object
# lbnl_tts_version_year          797958 non-null float64
# lbnl_tts                       797958 non-null object
# city                           798736 non-null object
# utility_clean                  1020303 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         998652 non-null object
# annual_PV_prod                 780969 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manuf2_clean                   231607 non-null object
# manuf3_clean                   209653 non-null object
# manuf1_clean                   201121 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# year                           68 non-null object
# pbi_length                     5427 non-null float64
# utility                        2117 non-null object
# bipv_3                         5255 non-null float64
# bipv_2                         5255 non-null float64
# bipv_1                         5255 non-null float64
# new_constr                     27106 non-null float64
# tracking                       1930 non-null float64
# 3rdparty                       306993 non-null float64
# dtypes: float64(17), object(22)
# memory usage: 303.6+ MB

# %%
# looks like these just suck i'm dropping them.

df.loc[df['zipcode'].isnull(), :]
# Out:
#        state date_installed  incentive_prog_names type  size_kw appraised  \
# 491       IN            NaN  no_incentive_program  NaN      NaN       NaN
# 283092    OH            NaN  no_incentive_program  NaN      NaN       NaN
# 283109    PA            NaN  no_incentive_program  NaN      NaN       NaN
# 283280    OH            NaN  no_incentive_program  NaN      NaN       NaN
# 283299    PA            NaN  no_incentive_program  NaN      NaN       NaN
#
#         zipcode install_type installer  cost_per_watt    ...     \
# 491         NaN  residential       NaN            NaN    ...
# 283092      NaN  residential       NaN            NaN    ...
# 283109      NaN  residential       NaN            NaN    ...
# 283280      NaN  residential       NaN            NaN    ...
# 283299      NaN  residential       NaN            NaN    ...
#
#        reported_annual_energy_prod  year pbi_length utility bipv_3 bipv_2  \
# 491                            NaN   NaN        NaN     NaN    NaN    NaN
# 283092                         NaN   NaN        NaN     NaN    NaN    NaN
# 283109                         NaN   NaN        NaN     NaN    NaN    NaN
# 283280                         NaN   NaN        NaN     NaN    NaN    NaN
# 283299                         NaN   NaN        NaN     NaN    NaN    NaN
#
#        bipv_1 new_constr  tracking  3rdparty
# 491       NaN        NaN       NaN       NaN
# 283092    NaN        NaN       NaN       NaN
# 283109    NaN        NaN       NaN       NaN
# 283280    NaN        NaN       NaN       NaN
# 283299    NaN        NaN       NaN       NaN
#
# [5 rows x 39 columns]

# %%
df = df.loc[df['zipcode'].notnull(), :]

# %%
df.to_sql('open_pv_clean', con=conn, if_exists="replace")

# %% [markdown]
# # Installer

# %%
# installer is probably going to be regionally dependent, so maybe we can just do something similar to utility?

df.installer.value_counts()
# Out:
# SolarCity                                              168125
# Vivint                                                  41615
# Sunpower                                                19925
# Verengo                                                 16396
# Sungevity                                               14939
# Rec Solar                                               14291
# PetersenDean                                            11235
# RGS/Real Goods                                          10951
# Sunrun                                                   9968
# Grid Alternatives                                        8119
# Trinity Heating & Air                                    7966
# Roof Diagnostics Solar & Electric                        6012
# Self                                                     5345
# American Solar Direct                                    4917
# Direct Energy Solar                                      4761
# American Solar Electric                                  4453
# Future Energy Corp                                       4215
# Sullivan Solar Power                                     4186
# Baker Electric                                           3591
# Solar Service Center                                     3295
# A1 Solar Power                                           3180
# Next Step Living                                         3172
# Solar Company                                            3043
# Horizon Solar Power                                      2660
# Solar Universe                                           2623
# Trinity Solar                                            2532
# Akeena                                                   2463
# Sun Valley Solar Solutions                               2348
# Heliopower                                               2147
# Semper Solaris Construction                              2095
#                                                         ...
# Innovative Energy Conservation                              1
# Economy Electric                                            1
# ESPINOZA                                                    1
# Forberg Construction Inc, dba Sunbolt EnergySystems         1
# Daryl Lueckenotte                                           1
# Suntechnics                                                 1
# George Waller                                               1
# Paladin Solar                                               1
# White House Solar                                           1
# ELECTRICAL & SOLAR                                          1
# Sam E Kornec                                                1
# Streetriderz                                                1
# Tamayo Electric                                             1
# Taft Emergency Lighting                                     1
# Gavilan Aviation                                            1
# Jospeh Sierra                                               1
# Adam Welsh Electric                                         1
# Jackson Mills Construction                                  1
# Stallcup and Sun Construction                               1
# Lockwood Electric Company                                   1
# Soal Forever                                                1
# Contructive Resource                                        1
# Cressman Consulting                                         1
# Wolfe Mottola Construction                                  1
# Russ Mills                                                  1
# Minden Electric                                             1
# Zachary Kaufman                                             1
# Ground Loop Heating & Air Conditioning                      1
# Allan Lewis                                                 1
# Ca Skyline Remodeling                                       1
# Name: installer, dtype: int64

# %%
# for state in states:
#     non_nulls = df.loc[df['state'] == state, 'installer'].notnull().sum()
#     if non_nulls == 0:
#         df.loc[df['state'] == state, 'utility_clean'] = "no utility listed"
#     else:
#         mode_utility = df.loc[df['state'] == state, 'utility_clean'].value_counts().index[0]
#         df.loc[df['state'] == state, 'utility_clean'] = mode_utility
        
# print df['utility_clean'].isnull().sum()

# %%
# doesn't look like there's necesarily a clear connection between county and installer.

mask = df['county'] == "Alameda"
county_installers = pd.DataFrame(df.loc[mask, :].groupby(['installer']).size()).sort_values(0, ascending=False)
county_installers
# Out:
#                                           0
# installer
# SolarCity                              4145
# Sungevity                               993
# PetersenDean                            799
# Solar Company                           496
# Sun Light & Power                       436
# Vivint                                  381
# Rec Solar                               361
# Grid Alternatives                       294
# RGS/Real Goods                          289
# Sunrun                                  278
# Solar Universe                          262
# Sky Power Systems                       258
# Bay Area Solar Solutions                249
# A1 Solar Power                          217
# Complete Solar Solution                 192
# Clean Solar                             170
# A1 Sun                                  166
# High Dedinition Solar                   162
# Next Energy                             157
# Solar Network Inc.                      147
# Diablo Solar Services                   146
# Sungate Energy Solutions                145
# Super Solar                             143
# Akeena                                  137
# Borrego Solar                           135
# Self                                    133
# American Solar Direct                   126
# Future Energy Corp                      126
# Verengo                                 121
# Sunpower                                119
# ...                                     ...
# Gmi Construction                          1
# Gloria Solar                              1
# Glenn Forslin dba- Automation Solar       1
# Glen Rand Concrete                        1
# Housing Construction Incorporation        1
# I E T S                                   1
# IC Equities LLC                           1
# Ideal Solar Solutions                     1
# Kimesmorris Construction                  1
# Kim Robinson                              1
# Killion Energy Dba Gci Solar              1
# Keene Builders Plumbers & Consultants     1
# Keen Builders                             1
# Kaspzak Consulting                        1
# Joseph Vierra                             1
# Jonathan A Vernot                         1
# John White                                1
# John Croll Construction                   1
# Jim Mccoy                                 1
# Jerry'S Plumbing & Electric               1
# Jason's Electric                          1
# James K. Collins                          1
# Jake Tornatzky                            1
# JTM Development                           1
# JP & Sun                                  1
# JC Innovative Energies                    1
# J & J Gas & Electric                      1
# Inviro Solutions Group                    1
# Intelisolar                               1
# advance home energy                       1
#
# [613 rows x 1 columns]

# %%
sc_percent = 4145./sum(county_installers.values)[0]

# %%
# solar city is 4 times bigger than the next biggest installer in alameda county and yet only as 26% of the installations.

sc_percent
# Out:
# 0.2679206256867688

# %%
# also, there's 10k installers... seems insane that I would actually use this as a feature.

len(df.installer.value_counts())
# Out:
# 10954

# %%
state_installers = []

for state in states:
    non_nulls = df.loc[df['state'] == state, 'installer'].notnull().sum()
    mode_installer = None
    if non_nulls == 0:
        print state, "no installers", 0
        mode_installer = "no installers"
    else:
        percent_biggest = float(df.loc[df['state'] == state, 'installer'].value_counts().values[0])/sum(df.loc[df['state'] == state, 'installer'].value_counts().values)
        print state, df.loc[df['state'] == state, 'installer'].value_counts().index[0], percent_biggest
        mode_installer = df.loc[df['state'] == state, 'installer'].value_counts().index[0]
    state_installers.append({
        "state": state,
        "mode_installer": mode_installer
    }
    )

state_mode_installers = pd.DataFrame(state_installers)
state_mode_installers
# Out:
# TX Advanced Solar & Electric 0.216222819448
# CA SolarCity 0.224797902416
# VA Paradise Energy Solutions 1.0
# WI Arch Electric - 297 0.0965189873418
# CO no installers 0
# MD SolarCity 0.170542635659
# OH Paradise Energy Solutions 1.0
# FL Solar Impact 0.115446285409
# NY Paradise Energy Solutions 0.897058823529
# MA SolarCity 0.286284866566
# DE Sungevity 0.170532060027
# WA no installers 0
# IA Ideal Energy 0.913793103448
# MS no installers 0
# IN Whole Sun Designs Inc 0.268421052632
# HI no installers 0
# KS SoCore Energy 1.0
# GA no installers 0
# ME ReVision Energy 0.565217391304
# NH Revision Energy 0.582706766917
# CT SolarCity 0.318886582835
# IL Solar Service 0.116161616162
# VT Integrated Solar and REC Solar 1.0
# NM Consolidated Solar Technologies 0.2031225605
# AL no installers 0
# MO Microgrid Solar Energy 0.158328752062
# KY Morton Solar, LLC 0.777777777778
# NJ Trinity Heating & Air 0.189569398491
# AK no installers 0
# MN All Energy Solar 0.212410501193
# MI no installers 0
# PA Direct Energy Solar 0.0714092140921
# MT no installers 0
# ID Creative Energies 0.428571428571
# SD Creative Energies 1.0
# UT no installers 0
# ND no installers 0
# RI no installers 0
# NE Nebraska Wind and Solar 1.0
# AZ SolarCity 0.426369111097
# TN no installers 0
# DC no installers 0
# OR Green Store 0.0769230769231
# LA Pontchartrain Mechanical 1.0
# AR Liberty Solar Solutions 0.204081632653
# WV no installers 0
# OK Paradise Energy Solutions 1.0
# WY no installers 0
# NC no installers 0
# NV SolarCity 0.521736120725
# SC no installers 0
# PR no installers 0
#                      mode_installer state
# 0         Advanced Solar & Electric    TX
# 1                         SolarCity    CA
# 2         Paradise Energy Solutions    VA
# 3               Arch Electric - 297    WI
# 4                     no installers    CO
# 5                         SolarCity    MD
# 6         Paradise Energy Solutions    OH
# 7                      Solar Impact    FL
# 8         Paradise Energy Solutions    NY
# 9                         SolarCity    MA
# 10                        Sungevity    DE
# 11                    no installers    WA
# 12                     Ideal Energy    IA
# 13                    no installers    MS
# 14            Whole Sun Designs Inc    IN
# 15                    no installers    HI
# 16                    SoCore Energy    KS
# 17                    no installers    GA
# 18                  ReVision Energy    ME
# 19                  Revision Energy    NH
# 20                        SolarCity    CT
# 21                    Solar Service    IL
# 22   Integrated Solar and REC Solar    VT
# 23  Consolidated Solar Technologies    NM
# 24                    no installers    AL
# 25           Microgrid Solar Energy    MO
# 26                Morton Solar, LLC    KY
# 27            Trinity Heating & Air    NJ
# 28                    no installers    AK
# 29                 All Energy Solar    MN
# 30                    no installers    MI
# 31              Direct Energy Solar    PA
# 32                    no installers    MT
# 33                Creative Energies    ID
# 34                Creative Energies    SD
# 35                    no installers    UT
# 36                    no installers    ND
# 37                    no installers    RI
# 38          Nebraska Wind and Solar    NE
# 39                        SolarCity    AZ
# 40                    no installers    TN
# 41                    no installers    DC
# 42                      Green Store    OR
# 43         Pontchartrain Mechanical    LA
# 44          Liberty Solar Solutions    AR
# 45                    no installers    WV
# 46        Paradise Energy Solutions    OK
# 47                    no installers    WY
# 48                    no installers    NC
# 49                        SolarCity    NV
# 50                    no installers    SC
# 51                    no installers    PR

# %%
df['installer'].value_counts()
# Out:
# SolarCity                                              168125
# Vivint                                                  41615
# Sunpower                                                19925
# Verengo                                                 16396
# Sungevity                                               14939
# Rec Solar                                               14291
# PetersenDean                                            11235
# RGS/Real Goods                                          10951
# Sunrun                                                   9968
# Grid Alternatives                                        8119
# Trinity Heating & Air                                    7966
# Roof Diagnostics Solar & Electric                        6012
# Self                                                     5345
# American Solar Direct                                    4917
# Direct Energy Solar                                      4761
# American Solar Electric                                  4453
# Future Energy Corp                                       4215
# Sullivan Solar Power                                     4186
# Baker Electric                                           3591
# Solar Service Center                                     3295
# A1 Solar Power                                           3180
# Next Step Living                                         3172
# Solar Company                                            3043
# Horizon Solar Power                                      2660
# Solar Universe                                           2623
# Trinity Solar                                            2532
# Akeena                                                   2463
# Sun Valley Solar Solutions                               2348
# Heliopower                                               2147
# Semper Solaris Construction                              2095
#                                                         ...
# Innovative Energy Conservation                              1
# Economy Electric                                            1
# ESPINOZA                                                    1
# Forberg Construction Inc, dba Sunbolt EnergySystems         1
# Daryl Lueckenotte                                           1
# Suntechnics                                                 1
# George Waller                                               1
# Paladin Solar                                               1
# White House Solar                                           1
# ELECTRICAL & SOLAR                                          1
# Sam E Kornec                                                1
# Streetriderz                                                1
# Tamayo Electric                                             1
# Taft Emergency Lighting                                     1
# Gavilan Aviation                                            1
# Jospeh Sierra                                               1
# Adam Welsh Electric                                         1
# Jackson Mills Construction                                  1
# Stallcup and Sun Construction                               1
# Lockwood Electric Company                                   1
# Soal Forever                                                1
# Contructive Resource                                        1
# Cressman Consulting                                         1
# Wolfe Mottola Construction                                  1
# Russ Mills                                                  1
# Minden Electric                                             1
# Zachary Kaufman                                             1
# Ground Loop Heating & Air Conditioning                      1
# Allan Lewis                                                 1
# Ca Skyline Remodeling                                       1
# Name: installer, dtype: int64

# %%
df.columns
# Out:
# Index([u'state', u'date_installed', u'incentive_prog_names', u'type',
#        u'size_kw', u'appraised', u'zipcode', u'install_type', u'installer',
#        u'cost_per_watt', u'cost', u'lbnl_tts_version_year', u'lbnl_tts',
#        u'city', u'utility_clean', u'tech_1', u'model1_clean', u'county',
#        u'annual_PV_prod', u'annual_insolation', u'rebate', u'sales_tax_cost',
#        u'tilt1', u'tracking_type', u'azimuth1', u'manuf2_clean',
#        u'manuf3_clean', u'manuf1_clean', u'inv_man_clean',
#        u'reported_annual_energy_prod', u'year', u'pbi_length', u'utility',
#        u'bipv_3', u'bipv_2', u'bipv_1', u'new_constr', u'tracking',
#        u'3rdparty'],
#       dtype='object')

# %%
# interesting, looks like solarcity doesn't install many mono systems, maybe we can assign all the blanks
# to solarcity if they're not mono, and see who the biggest installer is for mono and assign the rest to that one.


# should go work on tech_1 next, this seems really important.
# crystalline should probably be changed to "poly" because 
df.loc[df['installer'] == 'SolarCity', 'tech_1'].value_counts()
# Out:
# Poly           121271
# crystalline      2664
# Mono             2658
# CdTe              585
# Mono + a-Si       297
# CIGS                8
# a-Si                3
# Name: tech_1, dtype: int64

# %%
# sunpower appears to be far and away the biggest installer of these kind.

df.loc[df['tech_1'] == 'Mono', 'installer'].value_counts()
# Out:
# Sunpower                                                     14743
# RGS/Real Goods                                                5156
# Verengo                                                       4768
# PetersenDean                                                  4339
# Sungevity                                                     4107
# Future Energy Corp                                            3349
# Trinity Heating & Air                                         3135
# Baker Electric                                                2855
# Solar Company                                                 2760
# SolarCity                                                     2658
# A1 Solar Power                                                2356
# Sullivan Solar Power                                          1790
# Semper Solaris Construction                                   1724
# Akeena                                                        1633
# Self                                                          1572
# Leonard Roofing                                               1566
# Direct Energy Solar                                           1350
# Acro Energy Technologies                                      1262
# American Solar Electric                                       1131
# Cobalt Power Systems                                          1100
# Roof Diagnostics Solar & Electric                             1067
# Solar West Electric                                           1044
# Natural Energy                                                1018
# Smart Energy Solar                                             982
# Clean Solar                                                    979
# Sun Solar Energy Solutiions                                    960
# Elite Electric                                                 950
# Alternate Energy Systems                                       938
# Stellar Solar                                                  929
# Fralick Homes                                                  888
#                                                              ...
# M2 MULTIMEDIA INC.                                               1
# Patrick Epporson                                                 1
# Kevin French Dba Kns Electric Co                                 1
# Solar Cells Sales                                                1
# Fox Valley Technical College - 53560                             1
# Build It Green                                                   1
# All Phases & Trades Construction                                 1
# Domiciles For A New America                                      1
# Otis Bradley Company                                             1
# Talbot Solar Homes                                               1
# MacMichael Electric                                              1
# Dement Electric                                                  1
# pennies air conditioning, heating, solar and construction        1
# Prime Solar                                                      1
# On Target Electric                                               1
# Macgray Electric                                                 1
# Alexander's Construction                                         1
# Engineered Solar                                                 1
# K 2 Development Company                                          1
# Marcus Beale-Inter Faith Electric                                1
# Redco Engineering & Construction Corp                            1
# Ambassador Energy Socal                                          1
# she  engineering and construction group inc                      1
# Bay Electric                                                     1
# Neitzel Construction                                             1
# New England Solar & Electrical                                   1
# mr. solar constriction                                           1
# Solar Power Industries                                           1
# Denny Osburn Construction                                        1
# 5 cities corp                                                    1
# Name: installer, dtype: int64

# %%
df.loc[df['tech_1'] == 'Mono', 'installer'].notnull().sum()
# Out:
# 190005

# %%
df.loc[df['tech_1'] == 'Mono', 'installer'].value_counts()

# %%
df.loc[df['state'] == 'IL', 'installer'].value_counts()
# Out:
# Solar Service                                  46
# Kapital Electric                               32
# Solar Energy Of Illinois                       28
# Earth Wind & Solar Energy                      22
# Ailey Solar Electric                           22
# Self                                           20
# Renewable Energy Alternatives                  18
# Tick Tock Energy                               16
# Day & Night Solar                              14
# Nadler Electrical Contracting                  13
# Central Illinois Wind & Solar                  13
# Straightup Solar                               12
# Wcp Solar Services                             12
# Sunair Systems                                 11
# Windfree Wind & Solar                          10
# Morton Solar                                    7
# Tropic Construction                             7
# Title Electric Company                          6
# Renewable Alternative Energy                    5
# Magitek Energy Solutions                        5
# Whole Sun Designs Inc                           4
# Dale Balder Heavenly Winds                      3
# Continental Electrical Construction Co          3
# Midwest Wind & Solar                            3
# Eco Home Expert                                 3
# Ebener Construction                             2
# Eco Sun, Inc                                    2
# Energy Independence                             2
# Root Cellar                                     2
# John Root                                       2
#                                                ..
# Jim Anderson                                    1
# Boost Your Eco                                  1
# Jason Hark                                      1
# Sustain-A-Building                              1
# Juhl Energy                                     1
# Wilcox Electric & Service                       1
# homeowner                                       1
# Midwest Green Energy                            1
# Microgrid Solar Energy                          1
# Windsolarusa; Nadler Electrical Contracting     1
# Carlson Solar                                   1
# Akula                                           1
# Brightergy                                      1
# Habi-Tek - 3231                                 1
# New Prairie Construction                        1
# Schneider Electric                              1
# Solar Comfort                                   1
# Tim Ridgely                                     1
# Ace                                             1
# Envision Solar                                  1
# Independent Energy Systems                      1
# Off the Grid Solar LLC                          1
# Hoeper Green Power                              1
# ActiveX VT_ERROR:                               1
# Tri-City Electric Co                            1
# Southern Lights                                 1
# Solergy                                         1
# Hickey Electrical Contractors                   1
# Winsol Power Company                            1
# Convergence Energy                              1
# Name: installer, dtype: int64

# %%
# want to go through each row, and fill in with the mode installer in the state if there is one.
# if there isn't, fill with Sunpower if the tech_1 is mono, else fill with solarcity.

state_installers = {}

states = list(df.state.unique())

for state in states:
    non_nulls = df.loc[df['state'] == state, 'installer'].notnull().sum()
    mode_installer = None
    if non_nulls == 0:
        mode_installer = "no installers"
    else:
        mode_installer = df.loc[df['state'] == state, 'installer'].value_counts().index[0]
    state_installers[state] = mode_installer

# %%
df.installer.isnull().sum()
# Out:
# 317974

# %%
def fill_installer(row):
    # check to see if the installer category is null
    if row['installer'] is None:
        
        # checking if there are no installers listed in the state on this row.
        if state_installers[row['state']] == 'no installers':
            
            # if there are, check to see if tech is mono.
            if row['tech_1'] == "Mono":
                row['installer'] == "Sunpower"
            else:
                row['installer'] == "SolarCity"
        # if not no_installers, then we'll just set the null value to the mode installer from the state.
        else:    
            
            row['installer'] = state_installers[row['state']]
    
    return row

# %%
df = df.apply(fill_installer, axis=1)

# %%
df.to_sql("open_pv_clean_backup", con=conn, if_exists="replace")

# %%
df.to_sql("open_pv_clean", con=conn, if_exists="replace")

# %% [markdown]
# # Reimporting and doing some plotting!
#
# This is a bit of a tangent from the cleaning, I'm doing some plotting with plotly and making maps of some stuff.

# %%
df = pd.read_sql("SELECT * FROM open_pv_clean", con=conn)

# %%
import plotly

plotly.tools.set_credentials_file(username='ebaker12', api_key='removed_for_privacy')

# %%
df.columns
# Out:
# Index([u'state', u'date_installed', u'incentive_prog_names', u'type',
#        u'size_kw', u'appraised', u'zipcode', u'install_type', u'installer',
#        u'cost_per_watt', u'cost', u'lbnl_tts_version_year', u'lbnl_tts',
#        u'city', u'utility_clean', u'tech_1', u'model1_clean', u'county',
#        u'annual_PV_prod', u'annual_insolation', u'rebate', u'sales_tax_cost',
#        u'tilt1', u'tracking_type', u'azimuth1', u'manuf2_clean',
#        u'manuf3_clean', u'manuf1_clean', u'inv_man_clean',
#        u'reported_annual_energy_prod', u'year', u'pbi_length', u'utility',
#        u'bipv_3', u'bipv_2', u'bipv_1', u'new_constr', u'tracking',
#        u'3rdparty'],
#       dtype='object')

# %%
df_state.to_sql("state_level_data", con=conn)

# %%
state_size_cost_energy = df.loc[df['install_type'] == 'residential', ['state', 'size_kw', 'cost_per_watt', 'cost', 'annual_insolation', 'reported_annual_energy_prod']].groupby("state").mean()   

state_size_cost_energy['installations'] = df.groupby('state').size().values

state_size_cost_energy.reset_index(level=0, inplace=True)


df_state = state_size_cost_energy.copy()

# %%
import plotly.plotly as py

# scl = [[0.0, 'rgb(242,240,247)'],[0.2, 'rgb(218,218,235)'],[0.4, 'rgb(188,189,220)'],\
#             [0.6, 'rgb(158,154,200)'],[0.8, 'rgb(117,107,177)'],[1.0, 'rgb(84,39,143)']]


data = [ dict(
        type='choropleth',
        colorscale = "RdYlGn",
        autocolorscale = False,
        locations = df_state['state'],
        z = df_state['cost_per_watt'].astype(float),
        locationmode = 'USA-states',
        text = df_state['cost_per_watt'],
        marker = dict(
            line = dict (
                color = 'rgb(255,255,255)',
                width = 2
            )
        ),
        colorbar = dict(
            title = "Average Cost Per Watt"
        )
    ) ]

layout = dict(
        title = 'Average US Solar Cost Per Watt by State<br>(Hover for breakdown)',
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showlakes = True,
            lakecolor = 'rgb(255, 255, 255)',
        ),
    )

fig = dict( data=data, layout=layout )

url = py.plot( fig, filename='residential_avg_cost_per_watt' )

# %%
df.columns
# Out:
# Index([u'index', u'state', u'date_installed', u'incentive_prog_names', u'type',
#        u'size_kw', u'appraised', u'zipcode', u'install_type', u'installer',
#        u'cost_per_watt', u'cost', u'lbnl_tts_version_year', u'lbnl_tts',
#        u'city', u'utility_clean', u'tech_1', u'model1_clean', u'county',
#        u'annual_PV_prod', u'annual_insolation', u'rebate', u'sales_tax_cost',
#        u'tilt1', u'tracking_type', u'azimuth1', u'manuf2_clean',
#        u'manuf3_clean', u'manuf1_clean', u'inv_man_clean',
#        u'reported_annual_energy_prod', u'year', u'pbi_length', u'utility',
#        u'bipv_3', u'bipv_2', u'bipv_1', u'new_constr', u'tracking',
#        u'3rdparty'],
#       dtype='object')

# %%
df_ca = df.loc[((df['state'] == "CA") & (df['install_type'] == 'residential')), ['state', 'county', 'size_kw', 'cost_per_watt', 'cost', 'annual_insolation', 'reported_annual_energy_prod']].groupby("county").mean()

# %%
df_ca
# Out:
#                    size_kw  cost_per_watt  annual_insolation  \
# county
# Alameda           5.527480       6.934129           5.243357
# Alpine            3.896429      10.105714                NaN
# Amador            6.215012       6.513088           5.349896
# Butte             7.549414       6.117179           5.354022
# Calaveras         6.930538       6.512830           5.357959
# Colusa           10.614966       5.753081           5.315406
# Contra Costa      5.468173       6.732658           5.272811
# Del Norte         7.255985       5.327989           4.332815
# El Dorado         5.634495       6.336167           5.363019
# Fresno            7.406974       6.041925           5.656651
# Glenn             7.335138       5.787379           5.376248
# Humboldt          5.935827       7.062335           4.377707
# Imperial         13.348742       5.532320           5.560915
# Inyo              4.873658       5.855451           5.917772
# Kern              6.894975       5.819216           5.695999
# Kings             7.270359       5.747511           5.667427
# Lake              5.152800       6.949021           5.387071
# Lassen            6.001000       5.793667           5.464463
# Los Angeles       5.378254       6.189599           5.416213
# Madera            7.911624       6.123204           5.649968
# Marin             5.265064       7.161907           5.257310
# Mariposa          5.996395       6.464285           5.685922
# Mendocino         4.992723       7.156251           4.798091
# Merced            9.036354       5.730492           5.611888
# Modoc             7.800721       4.285305                NaN
# Mono              4.947147       6.751049           5.711069
# Monterey          4.982590       6.425584           5.293804
# Napa              8.948355       6.949724           5.338899
# Nevada            5.286424       6.777905           5.471274
# Orange            5.366701       6.464245           5.437985
# Placer           78.543670       6.331364           5.378083
# Plumas            3.912739       6.982141           5.791811
# Riverside         6.263822       5.738086           5.711035
# Sacramento        8.678539       5.534962           5.233548
# San Benito        5.704730       6.194702           5.240253
# San Bernardino    5.715225       5.886979           5.904885
# San Diego         5.858395       5.927377           5.560091
# San Francisco     4.364825       8.148515           5.246364
# San Joaquin       6.726643       6.094223           5.293234
# San Luis Obispo   5.131818       6.608923           5.739169
# San Mateo         5.330739       7.150199           5.242510
# Santa Barbara     6.235454       6.607674           5.691299
# Santa Clara       5.548720       6.614925           5.244620
# Santa Cruz        4.630158       6.990010           5.264287
# Shasta            7.665877       6.468431           4.366426
# Sierra            4.030000       7.541031           5.494057
# Siskiyou          8.117486       5.034984           4.921254
# Solano            5.577678       6.324332           5.340710
# Sonoma            5.935276       6.952024           5.287036
# Stanislaus        9.886107       6.022079           5.305731
# Sutter            7.181259       6.002332           5.352591
# Tehama            7.330186       6.023555           4.347223
# Trinity           5.674918       7.787315           4.370893
# Tulare            6.871255       5.750327           5.671736
# Tuolumne          6.605226       6.823625           5.394585
# Ventura           5.484369       6.261343           5.443706
# Yolo              5.701293       6.531907           5.363968
# Yuba              5.762969       6.511857           5.349686
#
#                  reported_annual_energy_prod
# county
# Alameda                                  NaN
# Alpine                                   NaN
# Amador                                   NaN
# Butte                                    NaN
# Calaveras                                NaN
# Colusa                                   NaN
# Contra Costa                             NaN
# Del Norte                        7528.000000
# El Dorado                        3565.000000
# Fresno                                   NaN
# Glenn                                    NaN
# Humboldt                                 NaN
# Imperial                        45746.778094
# Inyo                             8006.894737
# Kern                                     NaN
# Kings                                    NaN
# Lake                                     NaN
# Lassen                                   NaN
# Los Angeles                      8111.727693
# Madera                                   NaN
# Marin                                    NaN
# Mariposa                                 NaN
# Mendocino                                NaN
# Merced                                   NaN
# Modoc                           13383.555556
# Mono                                     NaN
# Monterey                                 NaN
# Napa                                     NaN
# Nevada                                   NaN
# Orange                                   NaN
# Placer                           8794.800000
# Plumas                                   NaN
# Riverside                       33961.792912
# Sacramento                      13988.969175
# San Benito                               NaN
# San Bernardino                   8256.232886
# San Diego                       64667.480000
# San Francisco                            NaN
# San Joaquin                              NaN
# San Luis Obispo                          NaN
# San Mateo                        8766.000000
# Santa Barbara                            NaN
# Santa Clara                      6138.995432
# Santa Cruz                               NaN
# Shasta                                   NaN
# Sierra                                   NaN
# Siskiyou                        12262.780488
# Solano                                   NaN
# Sonoma                                   NaN
# Stanislaus                               NaN
# Sutter                                   NaN
# Tehama                                   NaN
# Trinity                                  NaN
# Tulare                                   NaN
# Tuolumne                                 NaN
# Ventura                                  NaN
# Yolo                             7677.000000
# Yuba                                     NaN

# %%
df_ca_nonan = df_ca[['size_kw', 'cost_per_watt', 'annual_insolation']].dropna()

# %%
# looks like surprisingly, price is NEGATIVELY correlated with annual insolation, and not totally insignificantly.

# mapping this stuff could be interesting.

df_ca_nonan.corr()
# Out:
#                     size_kw  cost_per_watt  annual_insolation
# size_kw            1.000000      -0.112979           0.002515
# cost_per_watt     -0.112979       1.000000          -0.174306
# annual_insolation  0.002515      -0.174306           1.000000

# %% [markdown]
# # Back to data cleaning

# %%
import sqlite3
import pandas as pd
import numpy as np

conn = sqlite3.Connection("./capstone.sqlite")

df = pd.read_sql("SELECT * FROM open_pv_clean", con=conn)

# %%
# maybe we can impute cost? probably a function of technology and size.

# cost is an object, let's change that.

df['cost'].value_counts()
# Out:
# n/a          235867
# 30000.0        1572
# 25000.0        1443
# 20000.0        1276
# 22000.0        1236
# 24000.0        1186
# 27000.0        1047
# 21000.0        1035
# 33000.0        1025
# 18000.0         984
# 35000.0         897
# 40000.0         884
# 26000.0         874
# 28000.0         874
# 15000.0         869
# 28656.0         867
# 39402.0         848
# 19968.0         842
# 36000.0         837
# 24500.0         836
# 33432.0         834
# 35250.0         828
# 26268.0         807
# 26624.0         793
# 21492.0         773
# 45000.0         769
# 23000.0         763
# 27500.0         723
# 26400.0         720
# 23880.0         709
#               ...
# 278453.67         1
# 136312.0          1
# 12128.33          1
# 32577.6           1
# 39239.99          1
# 14907.63          1
# 12772.35          1
# 24396.2           1
# 1082000.0         1
# 17330.69          1
# 30101.43          1
# 22906.2           1
# 63273.75          1
# 10092.44          1
# 23032.32          1
# 37821.31          1
# 15912.23          1
# 30951.31          1
# 65628.0           1
# 25825.79          1
# 30129.05          1
# 10853.0           1
# 37140.73          1
# 30042.84          1
# 54236.19          1
# 33020.8           1
# 47989.5           1
# 22906.8           1
# 27207.2           1
# 1920.0            1
# Name: cost, dtype: int64

# %%
df.loc[df['cost'] == 'n/a', 'cost'] = np.nan

# %%
df['cost'] = pd.to_numeric(df['cost'])

# %%
df['tech_1'].value_counts()
# Out:
# Poly              350762
# Mono              215217
# crystalline         7439
# Mono + a-Si         5063
# CIGS                1097
# CdTe                 664
# a-Si                 480
# a-Si + Micro-c        60
# Thin Film             52
# CIS                   43
# multiple              42
# Name: tech_1, dtype: int64

# %%
# looks like size and kw are very highly correlated.

df[['cost', 'size_kw', 'annual_PV_prod']].corr()
# Out:
#                     cost   size_kw  annual_PV_prod
# cost            1.000000  0.940222        0.923671
# size_kw         0.940222  1.000000        0.999858
# annual_PV_prod  0.923671  0.999858        1.000000

# %%
df['install_type'].value_counts()
# Out:
# residential      970588
# commercial        36361
# government         5745
# nonprofit          4219
# educational        2702
# agricultural        396
# utility             230
# institutional        29
# public               28
# Name: install_type, dtype: int64

# %%
# Let's just make a simple linear regression using size as the feature and cost as the training and fill it in with
# that.

colors = {'residential':'red', 'commercial':'blue', 'government':'green', 'nonprofit':'black',
         'educational': 'yellow', 'agricultural': 'purple', 'utility': 'pink', 'institutional': 'brown',
         'public': 'orange'}


fig = plt.figure(figsize=(8,5))
plt.scatter(x=df['size_kw'], y=df['cost'], color=df['install_type'].apply(lambda x: colors[x]), alpha=0.4)

# %%
from sklearn.linear_model import LinearRegression

# %%
cost_size = df[['cost', 'size_kw']]
cost_size = cost_size.dropna()

# %%
lin_reg = LinearRegression()

# %%
cost_size.head()
# Out:
#        cost  size_kw
# 0  30600.53    10.56
# 1  40000.00    12.72
# 2  22665.58     5.40
# 3  28125.00     7.50
# 4  19250.00     5.00

# %%
X = cost_size['size_kw'].reshape((len(cost_size['size_kw']), 1))

lin_reg.fit(X=X, y=np.array(cost_size['cost']))
# Out:
# /anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
#
# reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
def fill_cost(row):
    if np.isnan(row['cost']) and not np.isnan(row['size_kw']):
        row['cost'] = lin_reg.predict(row['size_kw'])[0]
    return row

# %%
df = df.apply(fill_cost, axis=1)

# %%
df['cost'].isnull().sum()
# Out:
# 0

# %%
df.to_sql("open_pv_clean_backup", con=conn, if_exists="replace")

# %%
df.to_sql("open_pv_clean", con=conn, if_exists="replace")

# %% [markdown]
# # Moving to some Columns with Few Values

# %%
df = pd.read_sql("SELECT * FROM open_pv_clean", con=conn)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1020298 entries, 0 to 1020302
# Data columns (total 39 columns):
# state                          1020298 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020298 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      224036 non-null float64
# zipcode                        1020298 non-null float64
# install_type                   1020298 non-null object
# installer                      1008901 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           1020298 non-null float64
# lbnl_tts_version_year          797958 non-null float64
# lbnl_tts                       797958 non-null float64
# city                           798736 non-null object
# utility_clean                  1020298 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         998652 non-null object
# annual_PV_prod                 780969 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manuf2_clean                   231607 non-null object
# manuf3_clean                   209653 non-null object
# manuf1_clean                   201121 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# year                           68 non-null object
# pbi_length                     5427 non-null float64
# utility                        2117 non-null object
# bipv_3                         5255 non-null float64
# bipv_2                         5255 non-null float64
# bipv_1                         5255 non-null float64
# new_constr                     27106 non-null float64
# tracking                       1930 non-null float64
# 3rdparty                       306993 non-null float64
# dtypes: float64(20), object(19)
# memory usage: 311.4+ MB

# %%
# year and date installed are just all the same. ditching year.

df.loc[df.year.notnull(), ['year', 'date_installed']]
# Out:
#             year date_installed
# 179671  1/1/2006     01/01/2006
# 179752  1/1/2000     01/01/2000
# 179922  1/1/2008     01/01/2008
# 180066  1/1/2005     01/01/2005
# 180239  1/1/2002     01/01/2002
# 180341  1/1/2007     01/01/2007
# 180377  1/1/2001     01/01/2001
# 180515  1/1/2006     01/01/2006
# 180554  1/1/2007     01/01/2007
# 180700  1/1/2007     01/01/2007
# 180710  1/1/1999     01/01/1999
# 180753  1/1/2001     01/01/2001
# 180876  1/1/2007     01/01/2007
# 181021  1/1/2005     01/01/2005
# 181046  1/3/2000     01/03/2000
# 181079  1/1/2002     01/01/2002
# 250591  1/1/2006     01/01/2006
# 250605  1/1/2006     01/01/2006
# 250646  1/1/2007     01/01/2007
# 250667  1/1/2006     01/01/2006
# 250702  1/1/2007     01/01/2007
# 250945  1/1/2008     01/01/2008
# 251018  1/1/2007     01/01/2007
# 251057  1/1/2006     01/01/2006
# 251172  1/1/2008     01/01/2008
# 251212  1/1/2001     01/01/2001
# 251280  1/1/2007     01/01/2007
# 251304  1/1/2005     01/01/2005
# 251342  1/1/2006     01/01/2006
# 251345  1/1/2007     01/01/2007
# ...          ...            ...
# 251836  1/1/2007     01/01/2007
# 251851  1/1/2007     01/01/2007
# 251893      1999     02/24/1999
# 251993  1/1/2002     01/01/2002
# 252029  1/2/2007     01/02/2007
# 252105  1/1/2007     01/01/2007
# 252358      1999     02/24/1999
# 252456      1999     02/24/1999
# 252628  1/1/2007     01/01/2007
# 252701  1/1/2000     01/01/2000
# 252775  1/1/2007     01/01/2007
# 252826  1/1/2007     01/01/2007
# 252921  1/1/2007     01/01/2007
# 253047  1/1/2007     01/01/2007
# 253213  1/1/2007     01/01/2007
# 253290  1/1/2003     01/01/2003
# 253302  1/1/2008     01/01/2008
# 253311  1/1/2004     01/01/2004
# 253337  1/1/2002     01/01/2002
# 253354  1/1/2008     01/01/2008
# 253417  1/1/2007     01/01/2007
# 253444  1/1/2000     01/01/2000
# 253579  1/1/2008     01/01/2008
# 253597  1/1/2008     01/01/2008
# 253644  1/1/2007     01/01/2007
# 253760  1/1/2007     01/01/2007
# 253797  1/1/2007     01/01/2007
# 253806  1/1/2008     01/01/2008
# 253899  1/1/1999     01/01/1999
# 253945  1/1/2007     01/01/2007
#
# [68 rows x 2 columns]

# %%
del(df['year'])

# %%
# there's just too little information here to do anthing.

df['pbi_length'].value_counts()
# Out:
# 5.0     4466
# 20.0     863
# 1.0       98
# Name: pbi_length, dtype: int64

# %%
del(df['pbi_length'])

# %%
df.loc[df.utility.notnull(), 'utility_clean'] = df.loc[df.utility.notnull(), 'utility']

# %%
del[df['utility']]

# %%
# let's just make a new column for this, it's for buildings, just 1 or 0 if they have it.

df.loc[df['bipv_1'].notnull(), ['bipv_1', 'bipv_2', 'bipv_3']]
# Out:
#          bipv_1  bipv_2  bipv_3
# 97          1.0     1.0     1.0
# 2868        1.0     1.0     1.0
# 2869        1.0     1.0     1.0
# 2870        1.0     1.0     1.0
# 2871        1.0     1.0     1.0
# 2872        1.0     1.0     1.0
# 2873        1.0     1.0     1.0
# 2874        1.0     1.0     1.0
# 2875        1.0     1.0     1.0
# 2876        1.0     1.0     1.0
# 2877        1.0     1.0     1.0
# 3067        1.0     1.0     1.0
# 3254        1.0     1.0     1.0
# 3359        1.0     1.0     1.0
# 3360        1.0     1.0     1.0
# 3361        1.0     1.0     1.0
# 3363        1.0     1.0     1.0
# 3364        1.0     1.0     1.0
# 3365        1.0     1.0     1.0
# 3366        1.0     1.0     1.0
# 3368        1.0     1.0     1.0
# 3369        1.0     1.0     1.0
# 3370        1.0     1.0     1.0
# 3371        1.0     1.0     1.0
# 3372        1.0     1.0     1.0
# 3373        1.0     1.0     1.0
# 3375        1.0     1.0     1.0
# 3376        1.0     1.0     1.0
# 3377        1.0     1.0     1.0
# 3378        1.0     1.0     1.0
# ...         ...     ...     ...
# 1006618     1.0     1.0     1.0
# 1006619     1.0     1.0     1.0
# 1006620     1.0     1.0     1.0
# 1006621     1.0     1.0     1.0
# 1006622     1.0     1.0     1.0
# 1006623     1.0     1.0     1.0
# 1006624     1.0     1.0     1.0
# 1006625     1.0     1.0     1.0
# 1006626     1.0     1.0     1.0
# 1006627     1.0     1.0     1.0
# 1006628     1.0     1.0     1.0
# 1006629     1.0     1.0     1.0
# 1006842     1.0     1.0     1.0
# 1007464     1.0     1.0     1.0
# 1009048     1.0     1.0     1.0
# 1010372     1.0     1.0     1.0
# 1011632     1.0     1.0     1.0
# 1012205     1.0     1.0     1.0
# 1012940     1.0     1.0     1.0
# 1012944     1.0     1.0     1.0
# 1012945     1.0     1.0     1.0
# 1012946     1.0     1.0     1.0
# 1012947     1.0     1.0     1.0
# 1012948     1.0     1.0     1.0
# 1012949     1.0     1.0     1.0
# 1012950     1.0     1.0     1.0
# 1012951     1.0     1.0     1.0
# 1012952     1.0     1.0     1.0
# 1013027     1.0     1.0     1.0
# 1014121     1.0     1.0     1.0
#
# [5255 rows x 3 columns]

# %%
df['bipv'] = [1 if bipv == 1.0 else 0 for bipv in df['bipv_1']]

# %%
del(df['bipv_1'])
del(df['bipv_2'])
del(df['bipv_3'])

# %%
# I guess this is whether it's a new construction or somehting? i'll just fill na with 0

df['new_constr'].value_counts()
# Out:
# 1.0    27106
# Name: new_constr, dtype: int64

# %%
df['new_constr'].fillna(0, inplace=True)

# %%
# this probably corresponds to if these are "tracking" solar panels, we'll assume the ones that are blank are not,
# so just fill with 0

df['tracking'].value_counts()
# Out:
# 1.0    1930
# Name: tracking, dtype: int64

# %%
df['tracking'].fillna(0, inplace=True)

# %%
df.loc[df['manuf1_clean'].notnull(), ['manuf1_clean', 'manuf2_clean', 'manuf3_clean']].head(100)
# Out:
#                 manuf1_clean            manuf2_clean            manuf3_clean
# 0     Chint Solar (Zhejiang)  Chint Solar (Zhejiang)  Chint Solar (Zhejiang)
# 14    Phono Solar Technology  Phono Solar Technology  Phono Solar Technology
# 16    Phono Solar Technology  Phono Solar Technology  Phono Solar Technology
# 37        Westinghouse Solar      Westinghouse Solar      Westinghouse Solar
# 38        Westinghouse Solar      Westinghouse Solar      Westinghouse Solar
# 42                     Sharp                   Sharp                   Sharp
# 43                     Sharp                   Sharp                   Sharp
# 54                  SunPower                SunPower                SunPower
# 74                     Sharp                   Sharp                   Sharp
# 76                     Sharp                   Sharp                   Sharp
# 82                     Sharp                   Sharp                   Sharp
# 83                     Sharp                   Sharp                   Sharp
# 84                     Sharp                   Sharp                   Sharp
# 85                     Sharp                   Sharp                   Sharp
# 87                     Sharp                   Sharp                   Sharp
# 88                     Sharp                   Sharp                   Sharp
# 89                     Sharp                   Sharp                   Sharp
# 91            Canadian Solar          Canadian Solar          Canadian Solar
# 94                Schuco USA              Schuco USA              Schuco USA
# 98             Andalay Solar           Andalay Solar           Andalay Solar
# 99                  SunPower                SunPower                SunPower
# 101           Canadian Solar          Canadian Solar          Canadian Solar
# 499           Canadian Solar          Canadian Solar          Canadian Solar
# 510           Canadian Solar          Canadian Solar          Canadian Solar
# 517           Canadian Solar          Canadian Solar          Canadian Solar
# 522           Canadian Solar          Canadian Solar          Canadian Solar
# 531                 SunPower                SunPower                SunPower
# 532           Canadian Solar          Canadian Solar          Canadian Solar
# 536                    Sharp                   Sharp                   Sharp
# 537                    Sharp                   Sharp                   Sharp
# ...                      ...                     ...                     ...
# 710                 SunPower                SunPower                SunPower
# 721                    Sharp                   Sharp                   Sharp
# 723       Westinghouse Solar      Westinghouse Solar      Westinghouse Solar
# 724       Westinghouse Solar      Westinghouse Solar      Westinghouse Solar
# 725       Westinghouse Solar      Westinghouse Solar      Westinghouse Solar
# 726       Westinghouse Solar      Westinghouse Solar      Westinghouse Solar
# 727       Westinghouse Solar      Westinghouse Solar      Westinghouse Solar
# 732                    Sharp                   Sharp                   Sharp
# 736       Westinghouse Solar      Westinghouse Solar      Westinghouse Solar
# 737       Westinghouse Solar      Westinghouse Solar      Westinghouse Solar
# 738       Westinghouse Solar      Westinghouse Solar      Westinghouse Solar
# 743                 SunPower                SunPower                SunPower
# 745                 SunPower                SunPower                SunPower
# 748                 SunPower                SunPower                SunPower
# 752                    Sharp                   Sharp                   Sharp
# 2803          Canadian Solar          Canadian Solar          Canadian Solar
# 2804          Canadian Solar          Canadian Solar          Canadian Solar
# 2808                SunPower                SunPower                SunPower
# 2829          Canadian Solar          Canadian Solar          Canadian Solar
# 2835                SunPower                SunPower                SunPower
# 2840                SunPower                SunPower                SunPower
# 2847          Canadian Solar          Canadian Solar          Canadian Solar
# 2848          Canadian Solar          Canadian Solar          Canadian Solar
# 2851                SunPower                SunPower                SunPower
# 2857                SunPower                SunPower                SunPower
# 2866                SunPower                SunPower                SunPower
# 2867                SunPower                SunPower                SunPower
# 2880                SunPower                SunPower                SunPower
# 2881          Canadian Solar          Canadian Solar          Canadian Solar
# 2895                SunPower                SunPower                SunPower
#
# [100 rows x 3 columns]

# %%
del(df['manuf1_clean'])
del(df['manuf3_clean'])

# %%
df.rename(columns={'manuf2_clean': "manufacturer"}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1020298 entries, 0 to 1020302
# Data columns (total 32 columns):
# state                          1020298 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020298 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      224036 non-null float64
# zipcode                        1020298 non-null float64
# install_type                   1020298 non-null object
# installer                      1008901 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           1020298 non-null float64
# lbnl_tts_version_year          797958 non-null float64
# lbnl_tts                       797958 non-null float64
# city                           798736 non-null object
# utility_clean                  1020298 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         998652 non-null object
# annual_PV_prod                 780969 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manufacturer                   231607 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# new_constr                     1020298 non-null float64
# tracking                       1020298 non-null float64
# 3rdparty                       306993 non-null float64
# bipv                           1020298 non-null int64
# dtypes: float64(16), int64(1), object(15)
# memory usage: 256.9+ MB

# %%
# we may be able to fill in some manufacturer values, i wouldn't be surprised if it's really connected to
# installer,

# also may be connected to size and cost?

df.to_sql("open_pv_clean_backup", con=conn, if_exists='replace')

# %%
df.to_sql('open_pv_clean', con=conn, if_exists='replace')

# %%
# again just binary, going to fill with 0 for nas

df['appraised'].value_counts()
# Out:
# 0    796262
# 1    224036
# Name: appraised, dtype: int64

# %%
df['appraised'].fillna(0, inplace=True)

# %%
df['lbnl_tts_version_year'].value_counts()
# Out:
# 2016.0    797958
# Name: lbnl_tts_version_year, dtype: int64

# %%
df['lbnl_tts'].value_counts()
# Out:
# 1.0    797958
# Name: lbnl_tts, dtype: int64

# %%
# ok so either you have this thing or you don't the year is always 2016 just going to drop that shit
# and fill the other one with 0

del(df['lbnl_tts_version_year'])
df['lbnl_tts'].fillna(0, inplace=True)

# %% [markdown]
# # City

# %%
# loading in this mapping of zipcodes to locations, and we can just match the missing values with this.

city_zip = pd.read_csv("./free-zipcode-database-Primary.csv")

# %%
city_zip.columns
# Out:
# Index([u'Zipcode', u'ZipCodeType', u'City', u'State', u'LocationType', u'Lat',
#        u'Long', u'Location', u'Decommisioned', u'TaxReturnsFiled',
#        u'EstimatedPopulation', u'TotalWages'],
#       dtype='object')

# %%
city_zip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42522 entries, 0 to 42521
# Data columns (total 12 columns):
# Zipcode                42522 non-null int64
# ZipCodeType            42522 non-null object
# City                   42522 non-null object
# State                  42522 non-null object
# LocationType           42522 non-null object
# Lat                    41874 non-null float64
# Long                   41874 non-null float64
# Location               42521 non-null object
# Decommisioned          42522 non-null bool
# TaxReturnsFiled        28879 non-null float64
# EstimatedPopulation    28879 non-null float64
# TotalWages             28844 non-null float64
# dtypes: bool(1), float64(5), int64(1), object(5)
# memory usage: 3.6+ MB

# %%
def fill_city(row):
    if row['city'] is None:
        try:
            row['city'] = city_zip.loc[city_zip['Zipcode'] == int(row['zipcode']), 'City'].values[0]
        except:
            pass
    return row
    
df = df.apply(fill_city, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1020298 entries, 0 to 1020302
# Data columns (total 31 columns):
# state                          1020298 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020298 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      1020298 non-null int64
# zipcode                        1020298 non-null float64
# install_type                   1020298 non-null object
# installer                      702324 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           1020298 non-null float64
# lbnl_tts                       1020298 non-null object
# city                           798736 non-null object
# utility_clean                  1020298 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         998652 non-null object
# annual_PV_prod                 780969 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manufacturer                   231607 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# new_constr                     1020298 non-null float64
# tracking                       1020298 non-null float64
# 3rdparty                       306993 non-null float64
# bipv                           1020298 non-null int64
# dtypes: float64(13), int64(2), object(16)
# memory usage: 249.1+ MB

# %%
df.to_sql('open_pv_clean_backup', con=conn, if_exists='replace')

# %%
df.to_sql('open_pv_clean', con=conn, if_exists="replace")

# %% [markdown]
# # Starting May 11th

# %%
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
conn = sqlite3.Connection("./capstone.sqlite")

# %%
df = pd.read_sql('SELECT * FROM open_pv_clean', con=conn)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020298 entries, 0 to 1020297
# Data columns (total 33 columns):
# level_0                        1020298 non-null int64
# index                          1020298 non-null int64
# state                          1020298 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020298 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      1020298 non-null float64
# zipcode                        1020298 non-null float64
# install_type                   1020298 non-null object
# installer                      1008901 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           1020298 non-null float64
# lbnl_tts                       1020298 non-null float64
# city                           1020231 non-null object
# utility_clean                  1020298 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         998652 non-null object
# annual_PV_prod                 780969 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manufacturer                   231607 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# new_constr                     1020298 non-null float64
# tracking                       1020298 non-null float64
# 3rdparty                       306993 non-null float64
# bipv                           1020298 non-null int64
# dtypes: float64(15), int64(3), object(15)
# memory usage: 256.9+ MB

# %%
zipcode_df = pd.read_csv("./free-zipcode-database-Primary.csv")

# %%
# I want to do county, but it's going to be tough and there are so few missing values I'm just going to fill with no
# county

# %%
df.county.fillna("no_county", inplace=True)

# %%
df.tech_1.value_counts()
# Out:
# Poly              350762
# Mono              215217
# crystalline         7439
# Mono + a-Si         5063
# CIGS                1097
# CdTe                 664
# a-Si                 480
# a-Si + Micro-c        60
# Thin Film             52
# CIS                   43
# multiple              42
# Name: tech_1, dtype: int64

# %%
tech_costs = df[['tech_1', 'size_kw', 'cost']].groupby('tech_1').sum()

# %%
tech_costs['size/cost'] = tech_costs['size_kw']/tech_costs['cost']

# %%
# we could do a simple t-test to see if there's a difference between these two groups w/r/t cost, or even
# do markov chain monte carlo to see how big that difference is.
# Out:
#                      size_kw          cost  size/cost
# tech_1
# CIGS            4.288079e+04  2.039724e+08   0.000210
# CIS             5.676465e+03  2.884693e+07   0.000197
# CdTe            2.481990e+04  1.496098e+08   0.000166
# Mono            2.324888e+06  1.222352e+10   0.000190
# Mono + a-Si     5.230867e+04  3.701955e+08   0.000141
# Poly            4.291781e+06  2.134429e+10   0.000201
# Thin Film       4.913339e+02  2.610086e+06   0.000188
# a-Si            3.163014e+04  1.759568e+08   0.000180
# a-Si + Micro-c  1.560455e+03  9.841499e+06   0.000159
# crystalline     1.814794e+05  6.574054e+08   0.000276
# multiple        3.477210e+02  2.106018e+06   0.000165

# %%
mask_1 = df[df['tech_1'] == "Mono"]['cost_per_watt'].notnull()
mask_2 = df[df['tech_1'] == "Poly"]['cost_per_watt'].notnull()

# %%
# Hard to see that these distributions are any different...

fig = plt.figure(figsize=(10,7))
sns.distplot(df.loc[df['tech_1'] == "Mono", 'cost_per_watt'].dropna(), bins=40)
sns.distplot(df.loc[df['tech_1'] == "Poly", 'cost_per_watt'].dropna(), bins=40)
plt.xlim((0,13))
# Out:
# (0, 13)

# %%
from scipy.stats import ttest_ind

ttest_ind(df.loc[df['tech_1'] == "Mono", 'cost_per_watt'].dropna(), df.loc[df['tech_1'] == "Poly", 'cost_per_watt'].dropna(),
         equal_var = False)
# Out:
# Ttest_indResult(statistic=38.152721118064747, pvalue=0.0)

# %%
# I don't buy this result...

# maybe some companies only sell certain types of technology?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020298 entries, 0 to 1020297
# Data columns (total 33 columns):
# level_0                        1020298 non-null int64
# index                          1020298 non-null int64
# state                          1020298 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020298 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      1020298 non-null float64
# zipcode                        1020298 non-null float64
# install_type                   1020298 non-null object
# installer                      1008901 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           1020298 non-null float64
# lbnl_tts                       1020298 non-null float64
# city                           1020231 non-null object
# utility_clean                  1020298 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         1020298 non-null object
# annual_PV_prod                 780969 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manufacturer                   231607 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# new_constr                     1020298 non-null float64
# tracking                       1020298 non-null float64
# 3rdparty                       306993 non-null float64
# bipv                           1020298 non-null int64
# dtypes: float64(15), int64(3), object(15)
# memory usage: 256.9+ MB

# %%
installers_tech = df.groupby(["installer", 'tech_1']).size().reset_index()

# %%
installers_tech.sort_values(0, inplace=True, ascending=False)

# %%
# interesting that solarcity almost exclusively installs poly.  may be safe to just input poly to all the
# ones where the installer is solarcity

installers_tech
# Out:
#                                    installer       tech_1       0
# 9732                               SolarCity         Poly  131978
# 11481                                 Vivint         Poly   25296
# 7441               Paradise Energy Solutions         Poly   17868
# 10561                               Sunpower         Mono   14743
# 7439               Paradise Energy Solutions         Mono   13011
# 9730                               SolarCity         Mono   11608
# 8202                               Rec Solar         Poly   11098
# 11431                                Verengo         Poly    8364
# 10594                                 Sunrun         Poly    8236
# 10507                              Sungevity         Poly    7068
# 7594                            PetersenDean         Poly    5452
# 8062                          RGS/Real Goods         Mono    5156
# 11429                                Verengo         Mono    4768
# 794                    American Solar Direct         Poly    4407
# 7592                            PetersenDean         Mono    4339
# 10506                              Sungevity         Mono    4107
# 11193                  Trinity Heating & Air         Poly    3524
# 8064                          RGS/Real Goods         Poly    3396
# 4030                      Future Energy Corp         Mono    3349
# 11191                  Trinity Heating & Air         Mono    3208
# 360                Advanced Solar & Electric         Poly    3113
# 1201                          Baker Electric         Mono    2855
# 9735                               SolarCity  crystalline    2821
# 9335                           Solar Company         Mono    2760
# 798                  American Solar Electric         Poly    2557
# 358                Advanced Solar & Electric         Mono    2530
# 8922                                    Self         Poly    2484
# 8538       Roof Diagnostics Solar & Electric         Poly    2414
# 134                           A1 Solar Power         Mono    2356
# 9603                    Solar Service Center         Poly    2068
# ...                                      ...          ...     ...
# 2822                             David Aslan         Mono       1
# 8625                        Russell Hildreth         Poly       1
# 8624                        Russell Electric         Mono       1
# 8623           Russ Georgre DBA Electric Pro         Mono       1
# 8622             Ruscito Contracting & Solar         Mono       1
# 8621                    Rupiper Construction         Poly       1
# 2823                David Borquez Electrical         Mono       1
# 4570                                Greenify         Poly       1
# 6279                             Mark A Rego         Poly       1
# 2826                  David Crowell Electric  Mono + a-Si       1
# 8632                        Rwe Schott Solar         Mono       1
# 8634                        Rwe Schott Solar  crystalline       1
# 8651                          S J Electrical         Poly       1
# 2813                              Dave Morse         Poly       1
# 8650                          S J Electrical         Mono       1
# 8649           S D Deacon Corp Of California         Poly       1
# 8648   S C Cunningham Electrical Contracting         Poly       1
# 2809                Dave Bettis Construction         Poly       1
# 8646                   S & S Power Engineers         Poly       1
# 8645                   S & S Power Engineers         Mono       1
# 8644                        S & S Electrical         Poly       1
# 8643                          S & S Electric         Poly       1
# 8642          S & S Construction Restoration         Poly       1
# 6275                                   Marin         Poly       1
# 8640                      S & H Construction         Mono       1
# 8639                      S & B construction         Mono       1
# 8638                    Rynders Construction         Poly       1
# 6276                    Marin Septic Service         Poly       1
# 4571                          Greening House         Mono       1
# 12008                              wlf solar         Mono       1
#
# [12009 rows x 3 columns]

# %%
# It seems like for a lot of companies they have a main one that they do a lot of.  Just going to input based on
# installer mode.

print df.groupby(["installer", 'tech_1']).size()
# Out:
# installer                                                  tech_1
#  Earth Star Electric                                       Mono              3
#                                                            Poly              2
#                                                            a-Si              1
# 01 Electric                                                Poly              2
# 1 & 1 Electric                                             Poly              1
# 1 Code Green Solar                                         Poly              1
# 1 solar source                                             Mono              1
# 1-Star Energy                                              Poly              3
# 100% electric                                              Mono             36
#                                                            Poly              3
# 100% solar                                                 Mono              2
#                                                            Poly              4
# 1Au                                                        Poly              3
# 1B Electric Company                                        Mono              8
#                                                            Poly             40
# 1St Light Energy                                           CIGS              1
#                                                            Mono            226
#                                                            Mono + a-Si       1
#                                                            Poly           1010
#                                                            crystalline      11
# 1st impression                                             Mono              2
# 2 Brothers Contruction                                     Poly              1
# 2 G's Solar Electric                                       Mono              2
# 2 T Construction                                           Mono              3
#                                                            Poly              7
# 24/7 Electrical Services                                   Mono              2
#                                                            Poly              1
# 2500 R Group                                               Poly             34
# 2G'S Solar Electric                                        Mono             12
#                                                            Poly              6
#                                                                           ...
# interconsolar                                              Mono              3
# marilyn hansen                                             Poly              1
# michael kundysek electric                                  Poly              1
# mister tile                                                Mono              1
# mpr electric                                               Poly              1
# mr. solar constriction                                     Mono              1
# nexus nrg                                                  Poly              2
# nrg                                                        Mono              1
# one stop solar                                             Mono              5
# pe solar electrical                                        Mono              1
# pennies air conditioning, heating, solar and construction  Mono              1
#                                                            Poly              2
# pro-air inc                                                Mono              1
# robert and son trucking                                    Mono              1
# she  engineering and construction group inc                Mono              1
# sohilkarimy                                                Mono              1
# solar co                                                   Mono              2
#                                                            Poly              2
# solarology, inc.                                           Mono             16
#                                                            Poly             17
# solcon star                                                Mono              1
# streamline electric                                        Mono              1
# sunworksevolution                                          Poly              1
# swidler sales & consulting                                 Poly              1
# via solar corp                                             Mono            161
#                                                            Poly              1
# windsun energy systems                                     Mono             38
#                                                            Poly             10
# wiring innovations                                         Mono              3
# wlf solar                                                  Mono              1
# dtype: int64

# %%
installers = df.installer.unique().tolist()
installers.remove(None)

for installer in installers:
    non_nulls = df.loc[df['installer'] == installer, 'tech_1'].notnull().sum()
    if non_nulls == 0:
        df.loc[df['installer'] == installer, 'tech_1'].fillna("Poly", inplace=True)
    else:
        mode_tech = df.loc[df['installer'] == installer, 'tech_1'].value_counts().index[0]
        df.loc[df['installer'] == installer, 'tech_1'].fillna(mode_tech, inplace=True)
        
df['installer'].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-57-c817aeebf9a7> in <module>()
#       8     else:
#       9         mode_tech = df.loc[df['installer'] == installer, 'tech_1'].value_counts().index[0]
# ---> 10         df.loc[df['installer'] == installer, 'tech_1'].fillna(mode_tech, inplace=True)
#      11
#      12 df['installer'].isnull().sum()
#
# //anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in wrapper(self, other, axis)
#     853
#     854             with np.errstate(all='ignore'):
# --> 855                 res = na_op(values, other)
#     856             if isscalar(res):
#     857                 raise TypeError('Could not compare %s type with Series' %
#
# //anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in na_op(x, y)
#     757
#     758         if is_object_dtype(x.dtype):
# --> 759             result = _comp_method_OBJECT_ARRAY(op, x, y)
#     760         else:
#     761
#
# //anaconda/lib/python2.7/site-packages/pandas/core/ops.pyc in _comp_method_OBJECT_ARRAY(op, x, y)
#     737         result = lib.vec_compare(x, y, op)
#     738     else:
# --> 739         result = lib.scalar_compare(x, y, op)
#     740     return result
#     741
#
# KeyboardInterrupt:

# %%
# not sure I actually want to do this.

# %%
df['3rdparty'].value_counts()
# Out:
# 1.0    306993
# Name: 3rdparty, dtype: int64

# %%
df['3rdparty'].fillna(0, inplace=True)

# %% [markdown]
# # Reported annual PV and annual PV:
#
# These columns are really similar.
#
# One way to consolodate these could be to just merge the smaller one into the larger one where there are missing values.

# %%
df[['reported_annual_energy_prod', 'annual_PV_prod']]

# these are really just so similar.  Let's do it. # I've also graphed them before, there's really not too many places
# where they differ a lot.
# Out:
#          reported_annual_energy_prod  annual_PV_prod
# 0                            13836.0    14999.831600
# 1                            16419.0    17811.574390
# 2                             7235.0     7833.742822
# 3                             9340.0    10151.709590
# 4                             6729.0     7307.133789
# 5                             4407.0     4787.550469
# 6                             7391.0             NaN
# 7                             9168.0     9941.344116
# 8                             3145.0     3409.052637
# 9                             2474.0     5993.949463
# 10                            7778.0     8458.836445
# 11                            5849.0     6336.476697
# 12                            3450.0     3739.445640
# 13                            6079.0     6586.702648
# 14                            8076.0     8760.070313
# 15                            1601.0     1747.982510
# 16                            8076.0     8760.070313
# 17                               NaN     3662.563755
# 18                               NaN     3938.437925
# 19                               NaN             NaN
# 20                               NaN             NaN
# 21                               NaN             NaN
# 22                               NaN             NaN
# 23                               NaN             NaN
# 24                               NaN             NaN
# 25                               NaN             NaN
# 26                               NaN             NaN
# 27                               NaN             NaN
# 28                               NaN             NaN
# 29                               NaN             NaN
# ...                              ...             ...
# 1020268                          NaN             NaN
# 1020269                          NaN             NaN
# 1020270                          NaN             NaN
# 1020271                          NaN             NaN
# 1020272                          NaN             NaN
# 1020273                          NaN             NaN
# 1020274                          NaN             NaN
# 1020275                          NaN             NaN
# 1020276                          NaN             NaN
# 1020277                          NaN             NaN
# 1020278                          NaN             NaN
# 1020279                          NaN             NaN
# 1020280                          NaN             NaN
# 1020281                          NaN             NaN
# 1020282                          NaN             NaN
# 1020283                          NaN             NaN
# 1020284                          NaN             NaN
# 1020285                          NaN             NaN
# 1020286                          NaN             NaN
# 1020287                          NaN             NaN
# 1020288                          NaN             NaN
# 1020289                          NaN             NaN
# 1020290                          NaN             NaN
# 1020291                          NaN             NaN
# 1020292                          NaN             NaN
# 1020293                          NaN             NaN
# 1020294                          NaN             NaN
# 1020295                          NaN             NaN
# 1020296                          NaN             NaN
# 1020297                          NaN             NaN
#
# [1020298 rows x 2 columns]

# %%
df.annual_PV_prod.fillna(df.reported_annual_energy_prod, inplace=True)

# %%
df.annual_PV_prod.isnull().sum()
# Out:
# 232835

# %%
# I think that's really as good as we're going to get with this.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020298 entries, 0 to 1020297
# Data columns (total 33 columns):
# level_0                        1020298 non-null int64
# index                          1020298 non-null int64
# state                          1020298 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020298 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      1020298 non-null float64
# zipcode                        1020298 non-null float64
# install_type                   1020298 non-null object
# installer                      1008901 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           1020298 non-null float64
# lbnl_tts                       1020298 non-null float64
# city                           1020231 non-null object
# utility_clean                  1020298 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         1020298 non-null object
# annual_PV_prod                 787463 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manufacturer                   231607 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# new_constr                     1020298 non-null float64
# tracking                       1020298 non-null float64
# 3rdparty                       1020298 non-null float64
# bipv                           1020298 non-null int64
# dtypes: float64(15), int64(3), object(15)
# memory usage: 256.9+ MB

# %%
# That didn't seem to fill in too many values.

# %%
df.tracking_type.value_counts()
# Out:
# Fixed          524386
# Single-Axis       844
# Dual-Axis         541
# Mixed             287
# Name: tracking_type, dtype: int64

# %%
# I think we can just fill this with "no tracking", though for regression and stuff if we just onehot encode
# it shouldn't actually matter.

# %%
# seems like this is the manufacturer, but there's so little data it seems like this will be tough to use.

df['inv_man_clean'].value_counts()
# Out:
# SunPower                              42793
# Solectria                              3219
# Sharp                                  1873
# Schuco USA                             1185
# AU Optronics                            156
# GE Energy                               131
# MAGE Solar                              108
# Yes! Solar                               99
# CFM                                      80
# Siemens                                  72
# ET Solar Industry                        56
# Powercom                                 34
# Open Energy                              29
# Canadian Solar                           26
# LG Electronics Solar Cell Division       25
# Phono Solar Technology                   19
# Westinghouse Solar                       10
# Honeywell                                 7
# GreenVolts                                7
# Andalay Solar                             2
# Helios USA                                1
# Chint Solar (Zhejiang)                    1
# Name: inv_man_clean, dtype: int64

# %%
# could be helpful to map tilt, I'm wondering if it's geographically related.

df.tilt1.value_counts()
# Out:
# 18.000000     52203
# 20.000000     34293
# 23.000000     32851
# 22.000000     31975
# 30.000000     26932
# 25.000000     16157
# 19.000000     15432
# 15.000000     14359
# 21.000000     11479
# 26.000000     11378
# 24.000000     11295
# 27.000000     11082
# 10.000000     11038
# 17.000000     10411
# 14.000000      7677
# 35.000000      7387
# 16.000000      7017
# 40.000000      6568
# 5.000000       5802
# 34.000000      5702
# 28.000000      5256
# 45.000000      4442
# 32.000000      4237
# 12.000000      4042
# 33.000000      3674
# 37.000000      3082
# 13.000000      2920
# 38.000000      2236
# 36.000000      2233
# 31.000000      2119
#               ...
# 15.100000         1
# 10.400000         1
# 28.400000         1
# 19.800000         1
# 0.460000          1
# 19.200000         1
# 24.400000         1
# 19.300000         1
# 44.890000         1
# 18.700000         1
# 40.400000         1
# 175.000000        1
# 23.900000         1
# 0.270000          1
# 26.200001         1
# 260.000000        1
# 10.600000         1
# 160.000000        1
# 43.600000         1
# 30.830000         1
# 36.869999         1
# 2.760000          1
# 36.800000         1
# 74.000000         1
# 0.500000          1
# 29.800000         1
# 9.930000          1
# 0.170000          1
# 40.900000         1
# 12.900000         1
# Name: tilt1, dtype: int64

# %%
import plotly.plotly as py
import cufflinks as cf
import plotly.graph_objs as go

df_small = df.sample(10000)
lat_lon = pd.read_csv("./free-zipcode-database-Primary.csv")
lat_lon = lat_lon[['Zipcode', "Lat", "Long"]]
df_sub = df_small.merge(lat_lon, left_on="zipcode", right_on="Zipcode")

cat = dict(
    type = 'scattergeo',
    locationmode = 'USA-states',
    lat = df_sub['Lat'],
    lon = df_sub['Long'],
    text = df_sub['tilt1'],
    marker = dict(
        size = 10,
        color = df_small['tilt1'],
        line = dict(width=0.5, color='rgb(40,40,40)'),
        sizemode = 'area'
    ),
    name = 'tilt1')

layout = dict(
        title = 'tilt1 <br>(Click legend to toggle traces)',
        showlegend = True,
        geo = dict(
            scope='usa',
            projection=dict( type='albers usa' ),
            showland = True,
            landcolor = 'rgb(217, 217, 217)',
            subunitwidth=1,
            countrywidth=1,
            subunitcolor="rgb(255, 255, 255)",
            countrycolor="rgb(255, 255, 255)"
        ),
    )

fig = dict( data=[cat], layout=layout )
py.iplot( fig, validate=False, filename='tilt' )
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~ebaker12/30.embed" height="525px" width="100%"></iframe>

# %%
# looks like tilt has nothing to do with geography really, but probably more to do with something about constraints
# of the location where it's made, like the tilt of the roof it's on.

# not sure how I missed this, want to fill the rest of installer with SolarCity
df.installer.fillna("SolarCity", inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020298 entries, 0 to 1020297
# Data columns (total 33 columns):
# level_0                        1020298 non-null int64
# index                          1020298 non-null int64
# state                          1020298 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020298 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      1020298 non-null float64
# zipcode                        1020298 non-null float64
# install_type                   1020298 non-null object
# installer                      1020298 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           1020298 non-null float64
# lbnl_tts                       1020298 non-null float64
# city                           1020231 non-null object
# utility_clean                  1020298 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         1020298 non-null object
# annual_PV_prod                 787463 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         386729 non-null object
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manufacturer                   231607 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# new_constr                     1020298 non-null float64
# tracking                       1020298 non-null float64
# 3rdparty                       1020298 non-null float64
# bipv                           1020298 non-null int64
# dtypes: float64(15), int64(3), object(15)
# memory usage: 256.9+ MB

# %% [markdown]
# # Rebate

# %%
df.rebate = [str(rebate).replace("$", "").replace(",", "") for rebate in df.rebate]

# %%
df.rebate = [rebate if rebate != 'nan' else np.nan for rebate in df.rebate]

# %%
# I'm going to fill rebate with 0s where it's null, probably means there was no rebate.

df.rebate.fillna(0, inplace=True)

# %%
df.rebate = pd.to_numeric(df.rebate)

# %%
conn.text_factory = str

df.to_sql("open_pv_clean_backup", con=conn, if_exists='replace')

# %%
df.to_sql("open_pv_clean", con=conn, if_exists='replace')

# %% [markdown]
# # Date Installed.
#
# This is currently and object, let's make it a datetime.

# %%
df.date_installed = pd.to_datetime(df.date_installed)

# %% [markdown]
# # More Utility Cleaning
#
# Considering that we have so many installers, we may want to go ahead and limit it to say the top 10, or some smaller number that encapsulates a lot of the data, and then lump the rest in an "other utility" category.

# %%
# There are a few that really dominate our data set

# %%
# I messed up Utility Clean, I changed everything in the state instead of filling na...

df.groupby(['state', 'utility_clean']).size()
# Out:
# state  utility_clean
# AK     no utility listed                                       22
# AL     no utility listed                                       32
# AR     Arkansas Valley Electric Cooperative Corporation        10
#        C&amp;L Electric Cooperative Corporation                 1
#        Carroll Electric Coop Corp                               1
#        Carroll Electric Coop Corp - (AR)                        1
#        Carroll Electric Cooperative Corporation                10
#        Entergy Arkansas Inc                                   153
#        Entergy Arkansas, Inc.                                   6
#        First Electric Cooperative Corporation                   3
#        North Arkansas Electric Cooperative, Incorporated        4
#        Oklahoma Gas & Electric Co                               3
#        Oklahoma Gas and Electric Company (OG&amp;E)             3
#        Ozarks Electric Cooperative Corporation                  6
#        Petit Jean Electric Cooperative Corporation              2
#        Southwest Arkansas Electric                              1
#        Southwestern Electric Power Co                          32
#        Southwestern Electric Power Company (SWEPCO)             3
# AZ     Ajo Improvement Company                                  3
#        Arizona Public Service                               57985
#        Duncan Valley Electric Cooperative                       5
#        Graham County Electric Cooperative                     129
#        Mohave Electric Cooperative                            449
#        Morenci Water and Electric                               3
#        Navopache Electric Cooperative                         140
#        Salt River Project                                   15275
#        Sulphur Springs Valley Electric Cooperative           1266
#        Trico Electric Cooperative                            1357
#        Tucson Electric Power                                10921
#        UniSource Energy Services                             1827
#                                                             ...
# TX     Texas North Company                                     74
# UT     Rocky Mountain Power                                   815
# VA     no utility listed                                       50
# VT     Burlington Elec                                          1
#        Burlington Elec. Dept.                                   1
#        CVPS Corp                                              128
#        Conn. Valley Elec. Co.                                   1
#        GMP Corp.                                               73
#        Hardwick (Village of)                                    2
#        Hyde Park (Village of)                                   2
#        Lyndonville (Village of)                                 2
#        Morrisville (Village of)                                 1
#        Municipal (small areas)                                  1
#        Northfield Electric                                      1
#        Stowe (Village of)                                       4
#        Swanton (Village of)                                     1
#        VT Elec. Co-op                                          14
#        Wash. Elec Co-op                                        16
#        no utility listed                                     1394
# WA     no utility listed                                      209
# WI     Barron Electric Coop                                    13
#        Northern States Power Co                               134
#        Northern States Power Co - Wisconsin                    26
#        Superior Water and Light Co                              6
#        Superior Water, Light and Power Co                       1
#        Wisconsin Electric Power Co                           2626
#        Wisconsin Power & Light Co                             343
#        Wisconsin Public Service Corp                          172
# WV     no utility listed                                       92
# WY     no utility listed                                      157
# dtype: int64

# %%
df.utility_clean.value_counts()
# Out:
# Pacific Gas & Electric Company               352633
# Southern California Edison                   164476
# San Diego Gas & Electric Company              70941
# Arizona Public Service                        57985
# National Grid                                 52156
# JCP&L                                         25237
# PSEG Long Island                              24991
# Connecticut Light and Power                   21307
# Los Angeles Department of Water & Power       19757
# NSTAR (DBA EverSource)                        16698
# PSE&G BPU                                     15883
# Salt River Project                            15275
# Nevada Power                                  14102
# no utility listed                             12930
# Sacramento Municipal Utility District         11698
# Tucson Electric Power                         10921
# Baltimore Gas & Electric Co                   10349
# Austin Energy                                  9196
# AC Electric                                    8948
# Public Service Co of New Mexico                6090
# Consolidated Edison                            5894
# PPL Electric Utilities                         5892
# Delmarva                                       4602
# NYS Electric and Gas                           4081
# Ameren                                         4052
# Central Hudson Gas and Electric                4050
# Eversource Energy                              3643
# CPS Energy                                     3284
# WMECO (DBA EverSource)                         3153
# Orange and Rockland Utilities                  2881
#                                               ...
# AEP-TNC                                           1
# City of Anoka                                     1
# The Narragansett Electric Co                      1
# Alliant Energy                                    1
# Southeastern Illinois Electic Cooperative         1
# Ameren IP                                         1
# Norris Electric Coop                              1
# McDonough Power                                   1
# Freeborn-Mower Coop                               1
# Conn. Valley Elec. Co.                            1
# Willmar Public Utilities                          1
# Princeton Public Utilities                        1
# Burlington Elec                                   1
# MN Valley Co-op                                   1
# North American Power                              1
# Alliant                                           1
# Idaho Power Co                                    1
# Ohio Edison Co                                    1
# City of St. Peter                                 1
# Tri-County Electric                               1
# Marshall Municipal                                1
# KMU                                               1
# New Ulm Municipal                                 1
# WG&E                                              1
# Menard Electric. Coop                             1
# Ashland Elec. Dept.                               1
# Renville-Sibley Coop                              1
# Port of Oakland                                   1
# The Peoples Gas, Light and Coke Company           1
# Hull Municipal Light Plant                        1
# Name: utility_clean, dtype: int64

# %%
# This isn't actually SO long, but still it seems like we wouldn't lose too much by going
# from 400 to like 30 or 40

# %%
len(df.utility_clean.value_counts().tolist())
# Out:
# 441

# %%
print sum(df.utility_clean.value_counts()[0:50]), sum(df.utility_clean.value_counts()[50:])
# Out:
# 1000272 20026

# %%
# even just limiting to the top 30 gets 95% of our data

# for now I'm just going to use the top 50, we can always use even fewer.

# Before doing that, I'm going to look over an ordered list of the utilities and see if there are some
# mislabeled ones we can get rid of.

sorted_utils = sorted(df.utility_clean.value_counts().index.tolist())

# %% [markdown]
# # one's to change:
#
# - APE-T: AEP-TCC
# - Alliant
# - Ameren
# - Ashland
# - BHE
# - Burlington Elec
# - Carroll Electric Cooperative Corporation + Electric Cooperative Corporation
# - City of St Charles
# - ComEd = Commonwealth Edison Co
# - Connecticut Light
# - Coos-Curry Electric Coop
# - Delmarva
# - Duquesne
# - El Paso Electric
# - Entergy
# - Idaho Power Co
# - Carroll Energy = Jo Carrol Energy
# - Kit Carson Electric Coop
# - Littleton
# - Massachusetts Electric
# - McDonough Power
# - Menard Electric
# - MidAmerican Energy
# - Minnesota Power
# - NSTAR
# - Nicor Gas
# - Norris Elec = Norris Electric
# - North Shore Gas
# - Northern States Power Co
# - Oklahoma Gas = Oklahoma Gas and Eletric Company
# - Oncor not Concord
# - "Orange ": Orange and Rockland
# - Oregon Trail = Oregon Trail Coop
# - PECO
# - PPL Electric Utilities
# - Portland General Electric
# - Sierra Pacific
# - Southern California Edison
# - Southwestern Electric
# - Springfield
# - Superior Water: Superior Water and Light
# - The Potomac Edison Co
# - Tri-County Electric
# - Umatilla Electric Coop
# - Wasco Electric Coop
# - West Penn Power Co

# %%
sorted_utils
# Out:
# ['AC Electric',
#  'AEP-TCC',
#  'AEP-TNC',
#  'Adams Electric Cooperative',
#  'Ajo Improvement Company',
#  'Alexandria Light & Power',
#  'Allegheny (West Penn)',
#  'Alliant',
#  'Alliant Energy',
#  'Ameren',
#  'Ameren CILCO',
#  'Ameren CIPS',
#  'Ameren IP',
#  'Ameren Illinois Company',
#  'Ameren/CILCO',
#  'Ameren/CIPS',
#  'Ameren/IL',
#  'Ameren/IP',
#  'AmerenCILCO',
#  'AmerenCIPS',
#  'AmerenIP',
#  'AmeriGas',
#  'Arizona Public Service',
#  'Arkansas Valley Electric Cooperative Corporation',
#  'Arrowhead Coop',
#  'Ashburnham Municipal Light Plant',
#  'Ashland Elec. Dept.',
#  'Ashland, City Of',
#  'Atlantic City Electric Co',
#  'Austin Energy',
#  'Austin Public Utilities',
#  'BHE',
#  'BHE     ',
#  'Baltimore Gas & Electric Co',
#  'Bandon, City Of',
#  'Barron Electric Coop',
#  'Bear Valley Electric Service',
#  'Belmont Light',
#  'Beltrami Electric',
#  'Benco Electric Cooperative',
#  'Blachly-Lane County Coop. Electric Assn',
#  'BlueStar Energy Solutions',
#  'Boro of Milltown Elec',
#  'Boylston Electric Light Department',
#  'Brainerd Public Utilities',
#  'Braintree Electric Light Department',
#  'Brown County REA',
#  'Burbank Water and Power',
#  'Burlington Elec',
#  'Burlington Elec. Dept.',
#  'C&amp;L Electric Cooperative Corporation',
#  'CPS Energy',
#  'CVPS Corp',
#  'CWLP',
#  'Canby Utility Board',
#  'Carroll Electric Coop Corp',
#  'Carroll Electric Coop Corp - (AR)',
#  'Carroll Electric Cooperative Corporation',
#  'Cascade Locks, City of',
#  'Cascade Natural Gas',
#  'Central Electric Cooperative',
#  'Central Hudson Gas and Electric',
#  'Central Illinois Pub Serv Co',
#  'Central Lincoln PUD',
#  'Central Maine Power Co',
#  'Central Maine Power Company',
#  'Central New Mexico El Coop, Inc',
#  'Central New Mexico Electric Cooperative',
#  'Central Valley Electric Cooperative',
#  'Champion Energy, LLC',
#  'Chaska Public Utilties',
#  'Chester Municipal Electric Light Department',
#  'Chicopee Electric Light',
#  'Choptank Electric Coop, Inc',
#  'Citizens',
#  'City Water, Light and Power',
#  'City of Anoka',
#  'City of Farmington',
#  'City of Lompoc',
#  'City of Palo Alto Utilities',
#  'City of Riverside',
#  'City of San Francisco',
#  'City of St Charles',
#  'City of St Charles- (IL)',
#  'City of St. Peter',
#  'City of Truth or Consequences',
#  'City of Wadena',
#  'Clatskanie PUD',
#  'Clinton County Electric Cooperative',
#  'Colfax Electric',
#  'Columbia Basin Elec Cooperative, Inc',
#  'Columbia Power Cooperative',
#  'Columbia River PUD',
#  'Columbus Electric Cooperative',
#  'ComEd',
#  'Commonwealth Edison Co',
#  'Concord Municipal Light Plant',
#  'Conectiv',
#  'Conn. Valley Elec. Co.',
#  'Connecticut Light & Power Co',
#  'Connecticut Light and Power',
#  'Connecticut Municipal Electrical Energy Cooperative',
#  'Connexus Energy',
#  'Consolidated Edison',
#  'Constellation',
#  'Consumers Power, Inc.',
#  'Continental Divide Electric Cooperative',
#  'Coop Light & Power',
#  'Coos-Curry Electric Coop, Inc',
#  'Coos-Curry Electric Coop., Inc.',
#  'Corn Belt Energy Cooperative',
#  'Crow Wing Power',
#  'Curry',
#  'DIRECT ACCESS - APS',
#  'Dakota Electric Association',
#  'Danvers Electric',
#  'Dayton Power & Light Co',
#  'Delano Municpal',
#  'Delaware Electric Cooperative',
#  'Delaware Municipal Electric Corporation',
#  'Delmarva',
#  'Delmarva Power',
#  'Delmarva Power & Light Company',
#  'Detroit Lakes Public Utility',
#  'Devens Municipal Light',
#  'Direct Energy',
#  'Douglas Electric Coop., Inc.',
#  'Duke Energy Ohio Inc',
#  'Duncan Valley Electric Cooperative',
#  'Duquesne',
#  'Duquesne Light Co',
#  'East Central Coop',
#  'Eastern Maine Electric Co-op',
#  'Egyptian Electric Cooperative Association',
#  'El Paso Electric',
#  'El Paso Electric Co',
#  'Elk River Municipal',
#  'Ely PUC',
#  'Emerald PUD',
#  'Entergy',
#  'Entergy Arkansas Inc',
#  'Entergy Arkansas, Inc.',
#  'Eqyptian Electric',
#  'Eugene Water & Electric Board',
#  'Eversource Energy',
#  "Farmers' Electric Cooperative",
#  'First Electric Cooperative Corporation',
#  'First Energy (Pennsylvania Electric Co)',
#  'FirstEnergy',
#  'Florida Power & Light Co',
#  'Forest Grove, City Of',
#  'Fox Island Electric',
#  'Freeborn-Mower Coop',
#  'GMP Corp.',
#  'GPU BPU',
#  'Gainesville Regional Utilities',
#  'Gallup',
#  'Georgetown Municipal Light Department',
#  'Glencoe Light & Power Comm',
#  'Goodhue County Coop',
#  'Gosnold Electric Light Dept',
#  'Graham County Electric Cooperative',
#  'Grand Rapids Public Utilities',
#  'Groton Electric Light Department',
#  'Groveland Municipal Light Department',
#  'Gulf Power Co',
#  'HMLD',
#  'Hardwick (Village of)',
#  'Harney Electric Cooperative',
#  'Harvard Engineering & Utilities',
#  'Heritage Propane',
#  'Hetch Hetchy',
#  'Hibbing Public Utility',
#  'Hingham Municipal Lighting Plant',
#  'Holden Municipal Light Department  ',
#  'Holyoke Gas and Electric',
#  'Hood River Electric Cooperative',
#  'Hudson Light & Power ',
#  'Hull Municipal Light Plant',
#  'Hutchinson Utilities Commission',
#  'Hyde Park (Village of)',
#  'IL-Power',
#  'Idaho Power Co',
#  'Idaho Power Company',
#  'Illinois Power Co',
#  'Illinois Rural Electric Cooperative',
#  'Imperial Irrigation District',
#  'Integris Energy Services',
#  'Ipswich Municipal Light Department',
#  'Itasca Mantrap',
#  'JCP&L',
#  'Jemez Mountain Electric Cooperative',
#  'Jersey Central Power & Lt Co',
#  'Jo Carroll Energy',
#  'Jo-Carroll Energy',
#  'KBP&L',
#  'KLP',
#  'KMU',
#  'Kandiyohi County REA',
#  'Kansas City Power & Light - Greater Missouri Operations (GMO)',
#  'Kennebunk Light & Power Dist',
#  'Kit Carson Electric Coop, Inc',
#  'Kit Carson Electric Cooperative',
#  'LADWP',
#  'Lake Country Coop',
#  'Lake Region Electric Coop',
#  'Lane Electric Cooperative',
#  'Laverne Municipal Utility',
#  'Liberty Utilities',
#  'Littleton',
#  'Littleton Electric Light Department',
#  'Lodi Electric',
#  'Los Alamos County',
#  'Los Angeles Department of Water & Power',
#  'Lyndonville (Village of)',
#  'MN Valley Co-op',
#  'MPS',
#  'Mansfield Municipal Electric Department',
#  'Marblehead Municipal Light Department',
#  'Marshall Municipal ',
#  'Massachusetts Electric',
#  'Massachusetts Electric Co',
#  'Massachusetts Port Authority',
#  'McDonough Power',
#  'McDonough Power Coop',
#  'McDonough Power Cooperative',
#  'Mcminnville, City Of',
#  'Meeker Cooperative',
#  'Menard Electric Coop',
#  'Menard Electric Cooperative',
#  'Menard Electric. Coop',
#  'Merrimac Municipal Light Department',
#  'Met-Ed',
#  'Mid-America',
#  'MidAmerican Energy',
#  'MidAmerican Energy Co',
#  'Middleborough Gas & Electric',
#  'Middleton Electric Light Department',
#  'Midstate Electric Cooperative',
#  'Mille Lacs Energy Coop',
#  'Milton-Freewater, City Light & Power',
#  'Minnesota Power',
#  'Minnesota Power Inc',
#  'Minnesota Valley Electric',
#  'Mohave Electric Cooperative',
#  'Monmouth, City Of',
#  'Monroe County Electric Cooperative',
#  'Mora Municipal',
#  'Mora-San Miguel Electric Cooperative',
#  'Morenci Water and Electric',
#  'Morrisville (Village of)',
#  'Mount Carmel Public Utility',
#  'Mountain Lake Utilities',
#  'Municipal (small areas)',
#  'Municipal Utilities',
#  'NHEC',
#  'NJ Nat Gas BPU',
#  'NJR',
#  'NSTAR',
#  'NSTAR (DBA EverSource)',
#  'NSTAR Electric Company',
#  'NYS Electric and Gas',
#  'Nantucket Electric',
#  'National Grid',
#  'Navopache Electric Cooperative',
#  'Nevada Power',
#  'New Construction',
#  'New Jersey Power',
#  'New Ulm Municipal',
#  'Nicor Gas',
#  'Nicor Gas Company',
#  'Norris Elective Cooperative',
#  'Norris Electric Coop',
#  'North American Power',
#  'North Arkansas Electric Cooperative, Incorporated',
#  'North Attleborough Electric Dept',
#  'North Shore Gas',
#  'North Shore Gas Co',
#  'Northern Rio Arriba Electric Cooperative',
#  'Northern States Power Co',
#  'Northern States Power Co - Minnesota',
#  'Northern States Power Co - Wisconsin',
#  'Northern Wasco County PUD',
#  'Northfield Electric',
#  'Norwood Municipal Light',
#  'Ohio Edison Co',
#  'Ohio Power Co',
#  'Oklahoma Gas & Electric Co',
#  'Oklahoma Gas and Electric Company (OG&amp;E)',
#  'Oncor',
#  'Oncor Electric Delivery Company',
#  'Orange & Rockland Elec',
#  'Orange and Rockland Utilities',
#  'Oregon Trail Coop (was CP National Corp)',
#  'Oregon Trail El Cons Coop Inc',
#  'Oregon Trail El Cons Coop, Inc',
#  'Orlando Utilities Commission',
#  'Otero County Electric Cooperative',
#  'Other',
#  'Otter Tail Power',
#  'Ozarks Electric Cooperative Corporation',
#  'PECO',
#  'PECO Energy Co',
#  'PPL Electric Utilities',
#  'PPL Electric Utilities Corp',
#  'PSE&G BPU',
#  'PSEG Long Island',
#  'PSNH',
#  'PacifiCorp',
#  'Pacific Gas & Electric Company',
#  'Pacific Power & Light Company',
#  'Paxton Municipal Light Department',
#  'Peabody Municipal Light Plant',
#  'Pemberton',
#  'Penn Power',
#  'PennPwr',
#  'Pennsylvania Electric Co',
#  'Pennsylvania Power Co',
#  "People's Cooperative Services",
#  'Peoples',
#  'Petit Jean Electric Cooperative Corporation',
#  'Port of Oakland',
#  'Portland General Electric',
#  'Portland General Electric Co',
#  'Portland General Electric Company',
#  'Princeton Municipal Light',
#  'Princeton Public Utilities',
#  'Progress Energy Florida Inc',
#  'Public Service Co of NH',
#  'Public Service Co of NM',
#  'Public Service Co of New Mexico',
#  'Public Service Elec & Gas Co',
#  'Raton Public Service',
#  'Reading Municipal Light Department',
#  'Redwood Electric Cooperative',
#  'Reliant Electric',
#  'Renville-Sibley Coop',
#  'Rochester Gas and Electric',
#  'Rochester Public Utilities',
#  'Rocky Mountain Power',
#  'Roseville Electric',
#  'Rowley Municipal Lighting Plant',
#  'Runestone Electric Association',
#  'Rural Electric Convenience Cooperative Co.',
#  'Russell Municipal Light Department',
#  'SJ Gas',
#  'SWEPCO',
#  'Sacramento Municipal Utility District',
#  'Salem Electric',
#  'Salt River Project',
#  'San Diego Gas & Electric Company',
#  'San Miguel Electric Cooperative',
#  'Shakopee Public Utilities',
#  'Sharyland Utilities',
#  'Shelby Electric Cooperative',
#  'Shrewsbury Electric and Cable Operations (SELCO)',
#  'Sierra Electric Cooperative',
#  'Sierra Pacific',
#  'Sierra Pacific Power',
#  'Sierra Pacific Power Company',
#  'Sioux Valley Energy',
#  'Socorro Electric Cooperative',
#  'South Central Electric',
#  'South Hadley Electric Light Department',
#  'Southeastern Illinois Electic Cooperative',
#  'Southern California Edison',
#  'Southern California Edison Co',
#  'Southern Illinois Electric Cooperative',
#  'Southern Maryland Elec Coop Inc',
#  'Southwest Arkansas Electric',
#  'Southwestern Electric Cooperative',
#  'Southwestern Electric Power Co',
#  'Southwestern Electric Power Company',
#  'Southwestern Electric Power Company (SWEPCO)',
#  'Southwestern Public Service',
#  'Spoon River Electric Cooperative',
#  'Springer Electric Coop, Inc',
#  'Springer Electric Cooperative',
#  'Springfield Public Utilities',
#  'Springfield Utility Board',
#  'Stearns Electric Association',
#  'Steele Waseca',
#  'Sterling Municipal Light Department',
#  'Stowe (Village of)',
#  'Sulphur Springs Valley Electric Cooperative',
#  'Superior Water and Light Co',
#  'Superior Water, Light and Power Co',
#  'Surprise Valley Electrification Corp.',
#  'Swanton (Village of)',
#  'TNMP',
#  'Talquin Electric Coop, Inc',
#  'Taunton Municipal Lighting Plant',
#  'Templeton Municipal Light and Water Plant',
#  'Texas Central Company',
#  'Texas New Mexico Power Company',
#  'Texas North Company',
#  'The Narragansett Electric Co',
#  'The Peoples Gas, Light and Coke Company',
#  'The Potomac Edison Co',
#  'The Potomac Edison Company',
#  'Tillamook PUD',
#  'Todd Wadena Electric Coop',
#  'Town of Madison - (ME)',
#  'Tri-County Electric',
#  'Tri-County Electric Cooperative',
#  'Trico Electric Cooperative',
#  'Tucson Electric Power',
#  'UGI',
#  'Umatilla Electric Coop Assn',
#  'Umatilla Electric Cooperative',
#  'UniSource Energy Services',
#  'United Illuminating',
#  'Unitil',
#  'VT Elec. Co-op',
#  'Vineland Muni Elec',
#  'WG&E',
#  'WMECO (DBA EverSource)',
#  'Wakefield Municipal Gas & Light Department',
#  'Wasco Electric Coop, Inc',
#  'Wasco Electric Cooperative',
#  'Wash. Elec Co-op',
#  'Wayne-White Counties Electric Cooperative',
#  'Wellesley Municipal Light Plant',
#  'Wellsboro',
#  'West Boylston Municipal Lighting Plant',
#  'West Oregon Electric Cooperative, Inc.',
#  'West Penn Power Co',
#  'West Penn Power Company',
#  'Western Illinois Electrical Cooperative',
#  'Western Massachusetts Electric Company',
#  'Westfield Gas and Electric',
#  'Wild Rice Electric',
#  'Willmar Public Utilities',
#  'Wisconsin Electric Power Co',
#  'Wisconsin Power & Light Co',
#  'Wisconsin Public Service Corp',
#  'Wolfeboro Electric',
#  'Wright Hennepin REA',
#  'Xcel Energy',
#  'no utility listed',
#  'same']

# %%
# one's to change:

utility_map = {
    "APE-T": "AEP-TCC",
    "Alliant": "Alliant",
    "Ameren": "Ameren",
    "Ashland": "Ashland",
    "BHE": "BHE",
    "Burlington Elec": "Burlington Elec",
    "Electric Cooperative Corporation": "Carroll Electric Cooperative Corporation",  
    "City of St Charles": "City of St Charles",
    "ComEd": "Commonwealth Edison Co",
    "Connecticut Light": "Connecticut Light",
    "Coos-Curry Electric Coop": "Coos-Curry Electric Coop",
    "Delmarva": "Delmarva",
    "Duquesne": "Duquesne",
    "El Paso Electric": "El Paso Electric",
    "Entergy":  "Entergy",
    "Idaho Power Co": "Idaho Power Co",
    "Carroll Energy": "Jo Carrol Energy",
    "Kit Carson Electric Coop": "Kit Carson Electric Coop",
    "Littleton": "Littleton",
    "Massachusetts Electric": "Massachusetts Electric",
    "McDonough Power": "McDonough Power",
    "Menard Electric": "Menard Electric",
    "MidAmerican Energy": "MidAmerican Energy",
    "Minnesota Power": "Minnesota Power",
    "NSTAR": "NSTAR",
    "Nicor Gas": "Nicor Gas",
    "Norris Elec": "Norris Electric",
    "North Shore Gas": "North Shore Gas",
    "Northern States Power Co": "Northern States Power Co",
    "Oklahoma Gas": "Oklahoma Gas and Eletric Company",
    "Oncor": "Oncor",
    "Orange ": "Orange and Rockland",
    "Oregon Trail": "Oregon Trail Coop",
    "PECO": "PECO",
    "PPL Electric Utilities": "PPL Electric Utilities",
    "Portland General Electric": "Portland General Electric",
    "Sierra Pacific": "Sierra Pacific",
    "Southern California Edison": "Southern California Edison",
    "Southwestern Electric" : "Southwestern Electric",
    "Springfield": "Springfield",
    "Superior Water": "Superior Water and Light",
    "The Potomac Edison Co": "The Potomac Edison Co",
    "Tri-County Electric": "Tri-County Electric",
    "Umatilla Electric Coop": "Umatilla Electric Coop",
    "Wasco Electric Coop": "Wasco Electric Coop",
    "West Penn Power Co": "West Penn Power Co",
}

# %%
for key, value in utility_map.items():
    df.utility_clean = [value if key in utility else utility for utility in df.utility_clean]

# %%
# we got rid of a bunch :)

len(df.utility_clean.value_counts())
# Out:
# 370

# %%
# now we can do some grouping.

df.utility_clean.value_counts()
# Out:
# Pacific Gas & Electric Company               352633
# Southern California Edison                   167012
# San Diego Gas & Electric Company              70941
# Arizona Public Service                        57985
# National Grid                                 52156
# JCP&L                                         25237
# PSEG Long Island                              24991
# Connecticut Light                             21556
# Los Angeles Department of Water & Power       19757
# NSTAR                                         18373
# PSE&G BPU                                     15883
# Salt River Project                            15275
# Nevada Power                                  14102
# no utility listed                             12930
# Sacramento Municipal Utility District         11698
# Tucson Electric Power                         10921
# Baltimore Gas & Electric Co                   10349
# Austin Energy                                  9196
# AC Electric                                    8948
# PPL Electric Utilities                         6273
# Public Service Co of New Mexico                6090
# Consolidated Edison                            5894
# Delmarva                                       5088
# Ameren                                         4294
# NYS Electric and Gas                           4081
# Central Hudson Gas and Electric                4050
# Eversource Energy                              3643
# CPS Energy                                     3284
# Orange and Rockland                            3178
# WMECO (DBA EverSource)                         3153
#                                               ...
# AEP-TNC                                           1
# Southeastern Illinois Electic Cooperative         1
# The Peoples Gas, Light and Coke Company           1
# New Ulm Municipal                                 1
# Carroll Electric Coop Corp                        1
# Southwest Arkansas Electric                       1
# MN Valley Co-op                                   1
# NJ Nat Gas BPU                                    1
# Spoon River Electric Cooperative                  1
# Ohio Edison Co                                    1
# Carroll Electric Coop Corp - (AR)                 1
# Milton-Freewater, City Light & Power              1
# Central Maine Power Co                            1
# Hull Municipal Light Plant                        1
# Columbia Basin Elec Cooperative, Inc              1
# Princeton Public Utilities                        1
# NJR                                               1
# Swanton (Village of)                              1
# Town of Madison - (ME)                            1
# Norwood Municipal Light                           1
# same                                              1
# Curry                                             1
# CWLP                                              1
# Heritage Propane                                  1
# Morrisville (Village of)                          1
# Cascade Locks, City of                            1
# Fox Island Electric                               1
# Willmar Public Utilities                          1
# Conn. Valley Elec. Co.                            1
# Springer Electric Coop, Inc                       1
# Name: utility_clean, dtype: int64

# %%
# Making a list of the top 50 utilities and the "no utility listed" category
# will loop through these to do matching, and name ones that aren't in this "other"

top_50_utils = df.utility_clean.value_counts().index.tolist()[0:50]
top_50_utils.append("no utility listed")

# %%
df.utility_clean = [utility if utility in top_50_utils else "other" for utility in df.utility_clean]

# %%
# Reduced Utilities to top 50 and other.

len(df.utility_clean.value_counts())
# Out:
# 51

# %%
df.to_sql("open_pv_clean_backup", con=conn, if_exists='replace')

# %%
df.to_sql("open_pv_clean", con=conn, if_exists='replace')

# %% [markdown]
# # Incentive Programs
#
# I'd like to get down the number of incentive program names, similar to utility names.

# %%
# it's not actually too bad, but maybe there's some mislabeling?

len(df.incentive_prog_names.value_counts())
# Out:
# 66

# %%
# Doesn't look like there's much to be done here, just going to leave it be.

incentive_progs = sorted(df.incentive_prog_names.unique())
incentive_progs
# Out:
# ['Ajo Improvement Company',
#  'Ameren',
#  'Arizona Public Service',
#  'Arkansas State Energy Office',
#  'Austin Energy',
#  'Bear Valley Electric (California Center for Sustainable Energy)',
#  'CPS Energy',
#  'California Energy Commission (Emerging Renewables Program)',
#  'California Energy Commission (New Solar Homes Partnership)',
#  'California Public Utilities Commission (California Solar Initiative)',
#  'California Public Utilities Commission (Non-CSI Net Metered Systems)',
#  'California Public Utilities Commission (Self-Generation Incentive Program)',
#  'City of Palo Alto Utilities',
#  'Connecticut Clean Energy Finance and Investment Authority',
#  'Delaware Department of Natural Resources and Environmental Control',
#  'Duncan Valley Electric Cooperative',
#  'Efficiency Maine',
#  'El Paso Electric',
#  'Entergy',
#  'Florida Energy & Climate Commission',
#  'Gainesville Regional Utilities',
#  'Graham County Electric Cooperative',
#  'Illinois Department of Commerce & Economic Opportunity',
#  'Imperial Irrigation District',
#  'Kansas City Power & Light',
#  'Los Angeles Department of Water & Power',
#  'Maryland Energy Administration',
#  'Massachusetts Clean Energy Center',
#  'Massachusetts Department of Energy Resources',
#  'Minnesota Department of Commerce',
#  'Mohave Electric Cooperative',
#  'Morenci Water and Electric',
#  'NV Energy',
#  'Navopache Electric Cooperative',
#  'New Hampshire Public Utilities Commission',
#  'New Jersey Board of Public Utilities (CORE & REIP Programs)',
#  'New Jersey Board of Public Utilities (SREC Program)',
#  'New Mexico Energy, Minerals and Natural Resources Department',
#  'New York State Energy Research and Development Authority',
#  'Ohio Public Utilities Commission',
#  'Oncor Electric Delivery Company',
#  'Oregon Department of Energy',
#  'Orlando Utilities Commission',
#  'Pacific Power',
#  'Pacific Power (California Center for Sustainable Energy)',
#  'Pennsylvania Department of Environmental Protection',
#  'Pennsylvania Sustainable Development Fund',
#  'Rebuild a Greener San Diego (California Center for Sustainable Energy)',
#  'Rhode Island Office of Energy Resources',
#  'Rocky Mountain Power',
#  'Roseville Electric',
#  'Sacramento Municipal Utility District',
#  'Salt River Project',
#  'Sharyland Utilities',
#  'Southwestern Electric Power Company',
#  'Sulphur Springs Valley Electric Cooperative',
#  'Texas Central Company',
#  'Texas New Mexico Power Company',
#  'Texas North Company',
#  'Trico Electric Cooperative',
#  'Tucson Electric Power',
#  'UniSource Energy Services',
#  'Washington, DC Department of Energy & Environment',
#  'Washington, DC Public Service Commission',
#  'Wisconsin Focus on Energy',
#  'no_incentive_program']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1020298 entries, 0 to 1020302
# Data columns (total 31 columns):
# state                          1020298 non-null object
# date_installed                 1020298 non-null object
# incentive_prog_names           1020298 non-null object
# type                           1020298 non-null object
# size_kw                        1020298 non-null float64
# appraised                      1020298 non-null int64
# zipcode                        1020298 non-null float64
# install_type                   1020298 non-null object
# installer                      1020298 non-null object
# cost_per_watt                  762737 non-null float64
# cost                           1020298 non-null float64
# lbnl_tts                       1020298 non-null object
# city                           798736 non-null object
# utility_clean                  1020298 non-null object
# tech_1                         580919 non-null object
# model1_clean                   580919 non-null object
# county                         1020298 non-null object
# annual_PV_prod                 787463 non-null float64
# annual_insolation              780969 non-null float64
# rebate                         1020298 non-null float64
# sales_tax_cost                 355309 non-null float64
# tilt1                          383365 non-null float64
# tracking_type                  526058 non-null object
# azimuth1                       363281 non-null float64
# manufacturer                   231607 non-null object
# inv_man_clean                  49933 non-null object
# reported_annual_energy_prod    204429 non-null float64
# new_constr                     1020298 non-null float64
# tracking                       1020298 non-null float64
# 3rdparty                       1020298 non-null float64
# bipv                           1020298 non-null int64
# dtypes: float64(14), int64(2), object(15)
# memory usage: 249.1+ MB

# %% [markdown]
# ## Tracking + Tilt
#
# What is the tilt value for installations that have tracking?

# %%
mask = df[df['tracking'] = 1]

# %%
print df.loc[mask, 'tilt1'].isnull().sum()
print df.loc[mask, 'tilt1'].notnull().sum()

# if anything, having tracking makes it MORE likely that you'll have tilt listed.
# Out:
# 107807
# 116229

# %% [markdown]
# # Starting to Drop Columns and NAs to build Final Dataset.
#
# At this point it seems like I may have exhausted my ability to clean up this dataset much more.
#
# columns to include:
#
# - state
# - date_installed
# - incentive_prog_names
# - type
# - size_kw
# - appraised
# - zipcode
# - install_type
# - installer
# - cost_per_watt
# - lbnl_tts
# - utility_clean
# - model1_clean
# - annual_PV_prod
# - annual_insolation
# - tech_1
# - rebate
# - new_constr
# - tracking
# - 3rdparty
# - bipv

# %%
df_final = df[['state', 'date_installed', 'incentive_prog_names', 'type', 'size_kw', 'appraised', 'install_type',
              'installer', 'cost_per_watt', 'lbnl_tts', 'utility_clean', 'model1_clean', 'annual_PV_prod', 
              'annual_insolation', 'tech_1', 'rebate', 'new_constr', 'tracking', '3rdparty', 'bipv']]

# %%
# dropping any row where we don't have cost per watt, given that's ultimately what I'm interesting in predicting.

# It might actually be more interesting to look at predicting annual PV produced, but we can look into that later.

df_final = df_final[df_final.cost_per_watt.notnull()]

# %%
# there are some tough calls to make here, to drop the columns with null values, or to drop a bunch of rows.
# I could try training models both ways and see what happens.

df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 762737 entries, 0 to 1020297
# Data columns (total 20 columns):
# state                   762737 non-null object
# date_installed          762737 non-null object
# incentive_prog_names    762737 non-null object
# type                    762737 non-null object
# size_kw                 762737 non-null float64
# appraised               762737 non-null float64
# install_type            762737 non-null object
# installer               762737 non-null object
# cost_per_watt           762737 non-null float64
# lbnl_tts                762737 non-null float64
# utility_clean           762737 non-null object
# model1_clean            422387 non-null object
# annual_PV_prod          556526 non-null float64
# annual_insolation       550320 non-null float64
# tech_1                  422387 non-null object
# rebate                  762737 non-null float64
# new_constr              762737 non-null float64
# tracking                762737 non-null float64
# 3rdparty                762737 non-null float64
# bipv                    762737 non-null int64
# dtypes: float64(10), int64(1), object(9)
# memory usage: 122.2+ MB

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rand_for = RandomForestClassifier(max_features = 'auto', min_samples_split = 20)

# %%
from sklearn.model_selection import train_test_split

# %%
df_final.date_installed = pd.to_datetime(df_final.date_installed)

# %%
df_final.date_installed = pd.to_numeric(df_final.date_installed)

# %%
df_final.rename(columns = {'3rdparty': "third_party"}, inplace=True)

# %%
import patsy

formula = "cost_per_watt ~ state + date_installed + incentive_prog_names + type + size_kw + appraised + install_type + installer + lbnl_tts + utility_clean + rebate + new_constr + tracking + third_party + bipv"

# %%
y, X = patsy.dmatrices(formula, df_final, return_type = 'dataframe')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-114-30b35119b99b> in <module>()
# ----> 1 y, X = patsy.dmatrices(formula, df_final, return_type = 'dataframe')
#
# //anaconda/lib/python2.7/site-packages/patsy/highlevel.pyc in dmatrices(formula_like, data, eval_env, NA_action, return_type)
#     308     eval_env = EvalEnvironment.capture(eval_env, reference=1)
#     309     (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
# --> 310                                       NA_action, return_type)
#     311     if lhs.shape[1] == 0:
#     312         raise PatsyError("model is missing required outcome variables")
#
# //anaconda/lib/python2.7/site-packages/patsy/highlevel.pyc in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     167         return build_design_matrices(design_infos, data,
#     168                                      NA_action=NA_action,
# --> 169                                      return_type=return_type)
#     170     else:
#     171         # No builders, but maybe we can still get matrices
#
# //anaconda/lib/python2.7/site-packages/patsy/build.pyc in build_design_matrices(design_infos, data, NA_action, return_type, dtype)
#     931         results.append(_build_design_matrix(design_info,
#     932                                             factor_info_to_values,
# --> 933                                             dtype))
#     934     matrices = []
#     935     for need_reshape, matrix in results:
#
# //anaconda/lib/python2.7/site-packages/patsy/build.pyc in _build_design_matrix(design_info, factor_info_to_values, dtype)
#     767             m_slice = m[:, start_column:end_column]
#     768             _build_subterm(subterm, design_info.factor_infos,
# --> 769                            factor_to_values, m_slice)
#     770             start_column = end_column
#     771     assert start_column == m.shape[1]
#
# //anaconda/lib/python2.7/site-packages/patsy/build.pyc in _build_subterm(subterm, factor_infos, factor_values, out)
#     269                                      "containing missing values", factor)
#     270                 out[:, i] *= contrast.matrix[factor_values[factor],
# --> 271                                              column_idx]
#     272             else:
#     273                 assert factor_infos[factor].type == "numerical"
#
# KeyboardInterrupt:

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-30ffedcd787a> in <module>()
# ----> 1 train_test_split()
#
# //anaconda/lib/python2.7/site-packages/sklearn/model_selection/_split.pyc in train_test_split(*arrays, **options)
#    1675     n_arrays = len(arrays)
#    1676     if n_arrays == 0:
# -> 1677         raise ValueError("At least one array required as input")
#    1678     test_size = options.pop('test_size', None)
#    1679     train_size = options.pop('train_size', None)
#
# ValueError: At least one array required as input
